# %%
import numpy as np # linear algebra
import pandas as pd
from tqdm import tqdm
from glob import glob
from keras.layers import *
from keras.models import *
from keras.utils import *
import numpy as np
import os

# %%
'''
#!pip install livelossplot
# !python -m pip install --upgrade pip
# %matplotlib inline
# !pip install Livelossplot
'''
# Out:
# '\n#!pip install livelossplot\n!python -m pip install --upgrade pip\n%matplotlib inline\n!pip install Livelossplot\n'

# %%
# This Python 3 environment comes with many helpful analytics libraries installed
# It is defined by the kaggle/python Docker image: https://github.com/kaggle/docker-python
# For example, here's several helpful packages to load
#!pip install livelossplot
import numpy as np # linear algebra
import pandas as pd # data processing, CSV file I/O (e.g. pd.read_csv)

# Input data files are available in the read-only "../input/" directory
# For example, running this (by clicking run or pressing Shift+Enter) will list all files under the input directory

import os

import warnings
warnings.filterwarnings('ignore')
# %matplotlib inline
#!pip install Livelossplot
#from Livelossplot import PlotLossesKeras

from glob import glob
import os
import shutil

import numpy as np
import pandas as pd
# You can write up to 20GB to the current directory (/kaggle/working/) that gets preserved as output when you create a version using "Save & Run All" 
# You can also write temporary files to /kaggle/temp/, but they won't be saved outside of the current session

# %%
sampling_seed=0
size_4_training=78786
epoch_4_test=30
img_size=50
#training_reshape=(-1, img_size, img_size, 3)

# %% [markdown]
# # **Loading Training Files**

# %% [markdown]
# I have converted all images to numpy array to boost speed

# %%
os.makedirs('../working/data/train_seg/idc-minus/')     
os.makedirs('../working/data/train_seg/idc-plus/')  
os.makedirs('../working/data/test_seg/idc-minus/')     
os.makedirs('../working/data/test_seg/idc-plus/')  
os.makedirs('../working/data/val_seg/idc-minus/')     
os.makedirs('../working/data/val_seg/idc-plus/')  
os.mkdir('./History')

# %%
import random
from sklearn.model_selection import train_test_split

import shutil
from glob import glob 
#make directory for labelling

train_dir='../working/data/train_seg/'
validation_dir='../working/data/val_seg/'
#train_dir='../working/data/train_seg/'  
#test_dir = '../working/data/test_seg/normal'  
test_dir = '../working/data/test_seg/'  

class0 = [] # 0 = idc+
class1 = [] # 1 = idc-
imagePatches = glob('../input/breast-histopathology-images/IDC_regular_ps50_idx5/**/*.png', recursive=True)
for filename in imagePatches:
    if filename.endswith("class0.png"):
         class0.append(filename)
    else:
        class1.append(filename)

print(class0[0:10])

#sampling 10000 images from class 0 and class 1 to train the model

random.seed(sampling_seed)
class0sample=random.sample(class0,size_4_training)
class0label=np.zeros(size_4_training)
class1sample=random.sample(class1,size_4_training)
class1label=np.ones(size_4_training)

class0sample_train, class0sample_test1, class0label_train, class0label_test1 = train_test_split(class0sample, class0label, test_size=0.3, random_state=42)
class0sample_val, class0sample_test, class0label_val, class0label_test = train_test_split(class0sample_test1, class0label_test1, test_size=0.3, random_state=42)
print(len(class0sample_train))
print(len(class0sample_test))
print(len(class0sample_val))
class1sample_train, class1sample_test1, class1label_train, class1label_test1 = train_test_split(class1sample, class1label, test_size=0.3, random_state=42)
class1sample_val, class1sample_test, class1label_val, class1label_test = train_test_split(class1sample_test1, class1label_test1, test_size=0.3, random_state=42)
print(len(class1sample_train))
print(len(class1sample_test))
print(len(class1sample_val))
def read_and_save_data(path, file_name_array):
    j=0
    for i in file_name_array:
        if i.endswith('.png'):
          
            
            #second copy method
            head, tail = os.path.split(i)
            outputname=str(path+tail)
            #outputname=str(path+str(j)+'.png')
            #print(outputname)
            shutil.copy(i, outputname)
   
            #print(status2)
            
            j=j+1
            if j==120000:
                break
            
   
class0train_path='../working/data/train_seg/idc-minus/'
class1train_path='../working/data/train_seg/idc-plus/'
class0test_path='../working/data/test_seg/idc-minus/'
class1test_path='../working/data/test_seg/idc-plus/'
class0val_path='../working/data/val_seg/idc-minus/'
class1val_path='../working/data/val_seg/idc-plus/'

read_and_save_data(class0train_path,class0sample_train)
read_and_save_data(class1train_path,class1sample_train)


read_and_save_data(class0test_path,class0sample_test)
read_and_save_data(class1test_path,class1sample_test)


read_and_save_data(class0val_path,class0sample_val)
read_and_save_data(class1val_path,class1sample_val)
# Out:
# ['../input/breast-histopathology-images/IDC_regular_ps50_idx5/10295/0/10295_idx5_x1351_y1101_class0.png', '../input/breast-histopathology-images/IDC_regular_ps50_idx5/10295/0/10295_idx5_x1501_y501_class0.png', '../input/breast-histopathology-images/IDC_regular_ps50_idx5/10295/0/10295_idx5_x1501_y1101_class0.png', '../input/breast-histopathology-images/IDC_regular_ps50_idx5/10295/0/10295_idx5_x451_y901_class0.png', '../input/breast-histopathology-images/IDC_regular_ps50_idx5/10295/0/10295_idx5_x801_y451_class0.png', '../input/breast-histopathology-images/IDC_regular_ps50_idx5/10295/0/10295_idx5_x151_y1051_class0.png', '../input/breast-histopathology-images/IDC_regular_ps50_idx5/10295/0/10295_idx5_x1351_y901_class0.png', '../input/breast-histopathology-images/IDC_regular_ps50_idx5/10295/0/10295_idx5_x701_y651_class0.png', '../input/breast-histopathology-images/IDC_regular_ps50_idx5/10295/0/10295_idx5_x951_y1401_class0.png', '../input/breast-histopathology-images/IDC_regular_ps50_idx5/10295/0/10295_idx5_x601_y501_class0.png']
# 55150
# 7091
# 16545
# 55150
# 7091
# 16545

# %%
import os #Operating System
import sys #System
# train_generator = train_datagen.flow(x_train, y_train, batch_size =)
# val_generator = val_datagen.flow(x_val, y_val, batch_size = 64)
# test_generator=test_datagen.flow(x_test,y_test,batch_size = 64)

# %%
import os
import cv2
def readImage(path, tag):
    j=0
    image_data = []
    label=[]
    for i in os.listdir(path):
        imgname=path+i
        #print(imgname)
        img = cv2.imread(imgname, cv2.IMREAD_COLOR)
        img_resized = cv2.resize(img, (img_size,img_size), interpolation=cv2.INTER_LINEAR)
        image_data.append(img_resized)
        label.append(tag)
        #print(img[1])
        j=j+1
        #if j==10:
        #    break
        
    return image_data, label

import numpy as np
from tensorflow.keras.utils import *
from sklearn.utils import shuffle

class0_train, train0_label = readImage(class0train_path, 0)
class1_train, train1_label  = readImage(class1train_path, 1)
class0_test, test0_label = readImage(class0test_path, 0)
class1_test, test1_label = readImage(class1test_path, 1)
class0_val, val0_label = readImage(class0val_path, 0)
class1_val, val1_label = readImage(class1val_path, 1)

def Image_array_process(class0array,label0, class1array, label1):
    class0_array=np.array(class0array)
    class1_array=np.array(class1array)
    combined_data = np.concatenate((class0_array, class1_array))
    combined_label= np.concatenate((label0,label1), axis=0)
    assert len(combined_data) == len(combined_label)
    combined_data, combined_label = shuffle(combined_data, combined_label, random_state=0)
    print(combined_data.shape)
    length=len(combined_data)
    combined_label=to_categorical(combined_label,num_classes=2)
    #i=0
    #for i in range(length):
    #    print(combined_label[i])



    #print(class0_array.shape)
    #print(combined_data.shape)
    '''
    training_reshape=(224,224,3)
    length=len(combined_data)
    print(length)
    x =[None]*length
    #print(img_data.type)
    y =np.zeros(length)
    i=0
   
    for features,label in combined_data:
        x[i]=features
        #print(x.shape)
        y[i]=label
        #print(y[i])
        i=i+1
    
            #x = np.array(x).reshape(training_reshape)
    x = np.array(x)    
    #print(x.shape)
    #y=np.array(y)
    y=y.astype(int)
    y = to_categorical(y)
    print(y)
    '''  
    return combined_data, combined_label


X_train, y_train=Image_array_process(class0_train, train0_label, class1_train, train1_label)
X_test, y_test=Image_array_process(class0_test, test0_label, class1_test, test1_label)
X_val, y_val=Image_array_process(class0_val, val0_label, class1_val, val1_label)
# Out:
# (110300, 50, 50, 3)
# (14182, 50, 50, 3)
# (33090, 50, 50, 3)

# %%
'''
import numpy as np


class0_array = readImage(class0path, 0)
class1_array = readImage(class1path, 1)

class0_array=np.array(class0_array)
class1_array=np.array(class1_array)
combined_data = np.concatenate((class0_array, class1_array))
random.seed(41)
random.shuffle(combined_data)
print(class0_array.shape)
print(class1_array.shape)

X = []
y = []

for features,label in combined_data:
    X.append(features)
    y.append(label)
#print(X.shape)
#print(y.shape)

# reshape X data
train_data = np.array(X).reshape(training_reshape)
train_label=np.array(y)
print(y[19990:19999])
print(train_data.shape)
print(train_label.shape)
'''
# Out:
# '\nimport numpy as np\n\n\nclass0_array = readImage(class0path, 0)\nclass1_array = readImage(class1path, 1)\n\nclass0_array=np.array(class0_array)\nclass1_array=np.array(class1_array)\ncombined_data = np.concatenate((class0_array, class1_array))\nrandom.seed(41)\nrandom.shuffle(combined_data)\nprint(class0_array.shape)\nprint(class1_array.shape)\n\nX = []\ny = []\n\nfor features,label in combined_data:\n    X.append(features)\n    y.append(label)\n#print(X.shape)\n#print(y.shape)\n\n# reshape X data\ntrain_data = np.array(X).reshape(training_reshape)\ntrain_label=np.array(y)\nprint(y[19990:19999])\nprint(train_data.shape)\nprint(train_label.shape)\n'

# %%
'''
label_normal = np.zeros(len(normal))
label_bacterial = np.ones(len(bacterial))
label_viral = np.full(len(viral),2, dtype = int)
train_data = np.concatenate((normal,bacterial,viral),axis=0)
train_label = np.concatenate((label_normal,label_bacterial,label_viral),axis=0)
train_label.shape, train_data.shape
'''
# Out:
# '\nlabel_normal = np.zeros(len(normal))\nlabel_bacterial = np.ones(len(bacterial))\nlabel_viral = np.full(len(viral),2, dtype = int)\ntrain_data = np.concatenate((normal,bacterial,viral),axis=0)\ntrain_label = np.concatenate((label_normal,label_bacterial,label_viral),axis=0)\ntrain_label.shape, train_data.shape\n'

# %%
'''
#!pip install sklearn
from sklearn.model_selection import train_test_split
train_data, test1_data, train_label, test1_label = train_test_split(train_data, train_label, test_size=0.3, random_state=42)
val_data, test_data, val_label, test_label = train_test_split(test1_data, test1_label, test_size=0.3, random_state=42)
'''
# Out:
# '\n#!pip install sklearn\nfrom sklearn.model_selection import train_test_split\ntrain_data, test1_data, train_label, test1_label = train_test_split(train_data, train_label, test_size=0.3, random_state=42)\nval_data, test_data, val_label, test_label = train_test_split(test1_data, test1_label, test_size=0.3, random_state=42)\n'

# %%
train_data=X_train
train_label=y_train

test_data=X_test
test_label=y_test

val_data=X_val
val_label=y_val

# %% [markdown]
# ## Visualization

# %%
import matplotlib.pyplot as plt

# %% [markdown]
# ### Normal

# %% [markdown]
# # Viral

# %% [markdown]
# ## Bacterial

# %% [markdown]
# # Loading Test Data

# %% [markdown]
# ## Visualization

# %% [markdown]
# ## Normal

# %% [markdown]
# ## Viral

# %% [markdown]
# ## Bacterial

# %% [markdown]
# **Label encode**

# %% [markdown]
# # Dealing with Class Imbalance

# %% [markdown]
# # [CovXNet: A multi-dilation convolutional neural network for automatic COVID-19 and other pneumonia detection from chest X-ray images with transferable multi-receptive feature optimization](https://www.sciencedirect.com/science/article/pii/S0010482520302250)
#
# #### Code:[here](https://github.com/Perceptron21/CovXNet)
# ## Residual & Shifter Unit:
# ![Residual & Shifter Unit](https://ars.els-cdn.com/content/image/1-s2.0-S0010482520302250-gr2.jpg)
#
# ## Model:
# ![Model](https://ars.els-cdn.com/content/image/1-s2.0-S0010482520302250-gr4.jpg)

# %% [markdown]
# ## Residual Unit

# %%
def Residual_Unit(input_tensor, nb_of_input_channels, max_dilation, number_of_units):
    
  for i in range(number_of_units):
    x1 = Conv2D(nb_of_input_channels*2, kernel_size = (1,1), strides = (1,1), padding='same', dilation_rate= (1,1), activation='relu')(input_tensor)
    x1 = BatchNormalization()(x1)
  
    a = []

    for i in range(1, max_dilation+1):
      temp = DepthwiseConv2D( kernel_size=(3,3), dilation_rate = (i,i), padding = 'same', activation= 'relu')(x1)
      temp = BatchNormalization()(temp)
      a.append(temp)

    x = Concatenate(axis= -1)(a)
    x = Conv2D(nb_of_input_channels, kernel_size = (1,1), strides = (1,1), padding='same', dilation_rate= (1,1), activation='relu')(x)
    x = BatchNormalization()(x)

    x = Add()([x, input_tensor])

    input_tensor = x
  
  return x

# %% [markdown]
# ## Shifter Unit

# %%
# Shifter Unit:

def Shifter_Unit(input_tensor, nb_of_input_channels, max_dilation):
    x1 = Conv2D(nb_of_input_channels*4, kernel_size = (1,1), strides = (1,1), padding='same', dilation_rate= (1,1), activation='relu')(input_tensor)
    x1 = BatchNormalization()(x1)

    a = []

    for i in range(1, max_dilation+1):
      temp = DepthwiseConv2D( kernel_size=(3,3), dilation_rate = (i,i), padding = 'same', activation= 'relu')(x1)
      temp = MaxPool2D(pool_size=(2,2))(temp)
      temp = BatchNormalization()(temp)
      a.append(temp)

    x = Concatenate(axis= -1)(a)

    x = Conv2D(nb_of_input_channels*2, kernel_size = (1,1), strides = (1,1), padding='same', dilation_rate= (1,1), activation='relu')(x)
    x = BatchNormalization()(x)

    return x

# %% [markdown]
# # Network128

# %%
from tensorflow.keras.optimizers import Adam

# %%
#Network:
  
def Network128(input_shape, nb_class, depth):
  xin = Input(shape= input_shape)

  x = Conv2D(16, kernel_size = (5,5), strides= (1,1), padding = 'same', activation='relu')(xin)
  x = BatchNormalization()(x)

  x = Conv2D(32, kernel_size = (3,3), strides= (2,2), padding = 'same', activation='relu')(x)
  x = BatchNormalization()(x)
  
##Max Dilation rate will be vary in the range (1,5). 

# Max Dilation rate is 5 for tensor (64x64x32)
  x = Residual_Unit(input_tensor=x, nb_of_input_channels=32, max_dilation=5, number_of_units=depth)
  x = Shifter_Unit(input_tensor=x, nb_of_input_channels=32, max_dilation=5)


# Max Dilation rate is 4 for (32x32x64)
  x = Residual_Unit(input_tensor=x, nb_of_input_channels=64, max_dilation=4, number_of_units=depth)
  x = Shifter_Unit(input_tensor=x, nb_of_input_channels=64, max_dilation=4)

# Max Dilation rate is 3 for (16x16x128)
  x = Residual_Unit(input_tensor=x, nb_of_input_channels=128, max_dilation=3, number_of_units=depth)
  x = Shifter_Unit(input_tensor=x, nb_of_input_channels=128, max_dilation=3)

# Max Dilation rate is 2 for (8x8x256)
  x = Residual_Unit(input_tensor=x, nb_of_input_channels=256, max_dilation=2, number_of_units=depth)

  x = GlobalAveragePooling2D()(x)
  #x = GlobalMaxPooling2D()(x)

  x = Dense(128, activation='relu')(x)
  x = Dense(64, activation='relu')(x)

  x = Dense(nb_class, activation= 'softmax')(x)

  model = Model(xin, x)

  model.compile(loss='categorical_crossentropy', optimizer = Adam(lr = 1e-3), metrics = ['accuracy'])

  return model

# %% [markdown]
# # Custom Callback

# %%
# plot confusion matrix

import itertools
import numpy as np
import matplotlib.pyplot as plt
from sklearn.metrics import confusion_matrix
import pandas.util.testing as tm
from sklearn import metrics
import seaborn as sns
sns.set()

plt.rcParams["font.family"] = 'DejaVu Sans'

def plot_confusion_matrix(cm, classes,
                          normalize=False,
                          title='Confusion matrix',
                          cmap=plt.cm.Blues,
                          save = False):
    if normalize:
        cm = cm.astype('float') / cm.sum(axis=1)[:, np.newaxis]

    plt.imshow(cm, interpolation='nearest', cmap=cmap)
    plt.title(title)
    plt.colorbar()
    tick_marks = np.arange(len(classes))
    plt.xticks(tick_marks, classes, rotation=90)
    plt.yticks(tick_marks, classes)

    fmt = '.2f' if normalize else 'd'
    thresh = cm.max() / 2.
    for i, j in itertools.product(range(cm.shape[0]), range(cm.shape[1])):
        plt.text(j, i, format(cm[i, j], fmt),
                 horizontalalignment="center",
                 color="white" if cm[i, j] > thresh else "black")

    plt.tight_layout()
    plt.ylabel('True label')
    plt.xlabel('Predicted label')
    plt.grid(b=False)
    if save == True:
      plt.savefig('Confusion Matrix.png', dpi = 900)

# %%
# test model performance
from datetime import datetime
import matplotlib.pyplot as plt


def test_model(model, test_generator, y_test, class_labels, cm_normalize=True, \
                 print_cm=True):
    
    # BS = 16
    results = dict()
    
    # n = len(testy)// BS

    # testX = testX[:BS*n]
    # testy = testy[:BS*n]

    print('Predicting test data')
    test_start_time = datetime.now()
    y_pred_original = model.predict_generator(test_generator,verbose=1)
    # y_pred = (y_pred_original>0.5).astype('int')

    y_pred = np.argmax(y_pred_original, axis = 1)
    # y_test = np.argmax(testy, axis= 1)
    #y_test = np.argmax(testy, axis=-1)
    
    test_end_time = datetime.now()
    print('Done \n \n')
    results['testing_time'] = test_end_time - test_start_time
    print('testing time(HH:MM:SS:ms) - {}\n\n'.format(results['testing_time']))
    results['predicted'] = y_pred
    y_test = y_test.astype(int) # sparse form not categorical
    

    # balanced_accuracy
    from sklearn.metrics import balanced_accuracy_score
    balanced_accuracy = balanced_accuracy_score(y_true=y_test, y_pred=y_pred)
    print('---------------------')
    print('| Balanced Accuracy  |')
    print('---------------------')
    print('\n    {}\n\n'.format(balanced_accuracy))

    
    # calculate overall accuracty of the model
    accuracy = metrics.accuracy_score(y_true=y_test, y_pred=y_pred)
    # store accuracy in results
    results['accuracy'] = accuracy
    print('---------------------')
    print('|      Accuracy      |')
    print('---------------------')
    print('\n    {}\n\n'.format(accuracy))
    

    # get classification report
    print('-------------------------')
    print('| Classifiction Report |')
    print('-------------------------')
    classification_report = metrics.classification_report(y_test, y_pred)
    # store report in results
    results['classification_report'] = classification_report
    print(classification_report)
    
    
    
    # confusion matrix
    cm = metrics.confusion_matrix(y_test, y_pred)
    results['confusion_matrix'] = cm
    if print_cm: 
        print('--------------------')
        print('| Confusion Matrix |')
        print('--------------------')
        print('\n {}'.format(cm))
        
    # plot confusin matrix
    plt.figure(figsize=(6,4))
    plt.grid(b=False)
    plot_confusion_matrix(cm, classes=class_labels, normalize=True, title='Normalized confusion matrix')
    plt.show()
    

    
    # add the trained  model to the results
    results['model'] = model
    
    return


from keras.callbacks import Callback
class MyLogger(Callback):
  
  def __init__(self, test_generator, y_test, class_labels):
    super(MyLogger, self).__init__()
    self.test_generator = test_generator
    self.y_test = y_test
    self.class_labels = class_labels
    
  def on_epoch_end(self, epoch, logs=None):
    test_model(self.model, self.test_generator, self.y_test, self.class_labels)

# %%
from datetime import datetime
import matplotlib.pyplot as plt
from sklearn.metrics import f1_score, roc_auc_score, cohen_kappa_score, precision_score, recall_score, accuracy_score, confusion_matrix

from datetime import datetime
import matplotlib.pyplot as plt
from sklearn.metrics import f1_score, roc_auc_score, cohen_kappa_score, precision_score, recall_score, accuracy_score, confusion_matrix

def test_final_model(model, train_generator, test_generator, val_generator, y_train, y_test, y_val, class_labels, cm_normalize=True, \
                 print_cm=True):
    
    # BS = 16
    results = dict()
    
    # n = len(testy)// BS

    # testX = testX[:BS*n]
    # testy = testy[:BS*n]

    print('Predicting test data')
    test_start_time = datetime.now()
    y_pred_test_original = model.predict_generator(test_generator,verbose=1)
    # y_pred = (y_pred_test>0.5).astype('int')

    y_pred_test = np.argmax(y_pred_test_original, axis = 1)
    
    y_train = y_train.astype(int) # sparse form not categorical
    y_val = y_val.astype(int) # sparse form not categorical
    # y_test = np.argmax(testy, axis= 1)
    #y_test = np.argmax(testy, axis=-1)
    
    test_end_time = datetime.now()
    print('Done \n \n')
    results['testing_time'] = test_end_time - test_start_time
    print('testing time(HH:MM:SS:ms) - {}\n\n'.format(results['testing_time']))
    results['predicted'] = y_pred_test
    y_test = y_test.astype(int) # sparse form not categorical
    

    # balanced_accuracy
    from sklearn.metrics import balanced_accuracy_score
    balanced_accuracy = balanced_accuracy_score(y_true=y_test, y_pred=y_pred_test)
    print('---------------------')
    print('| Balanced Accuracy  |')
    print('---------------------')
    print('\n    {}\n\n'.format(balanced_accuracy))

    
    # calculate overall accuracty of the model
    accuracy = metrics.accuracy_score(y_true=y_test, y_pred=y_pred_test)
    # store accuracy in results
    results['accuracy'] = accuracy
    print('---------------------')
    print('|      Accuracy      |')
    print('---------------------')
    print('\n    {}\n\n'.format(accuracy))
    

    # get classification report
    print('-------------------------')
    print('| Classifiction Report |')
    print('-------------------------')
    classification_report = metrics.classification_report(y_test, y_pred_test)
    # store report in results
    results['classification_report'] = classification_report
    print(classification_report)
    
    
    
    # confusion matrix
    cm = metrics.confusion_matrix(y_test, y_pred_test)
    results['confusion_matrix'] = cm
    if print_cm: 
        print('--------------------')
        print('| Confusion Matrix |')
        print('--------------------')
        print('\n {}'.format(cm))
        
    # plot confusin matrix
    plt.figure(figsize=(6,4))
    plt.grid(b=False)
    plot_confusion_matrix(cm, classes=class_labels, normalize=True, title='Normalized confusion matrix')
    plt.show()
    

    
    # add the trained  model to the results
    results['model'] = model
    print("calculate other score")
    print("predicting validation data")

    #calculate other score
    y_pred_val_original = model.predict_generator(val_generator,verbose=1)
    # y_pred = (y_pred_val>0.5).astype('int')

    y_pred_val = np.argmax(y_pred_val_original, axis = 1)
    # y_val = np.argmax(valy, axis= 1)
    #y_val = np.argmax(valy, axis=-1)
    print("predicting test data")
    y_pred_train_original = model.predict_generator(train_generator,verbose=1)
    # y_pred = (y_pred_train>0.5).astype('int')

    y_pred_train = np.argmax(y_pred_train_original, axis = 1)
    # y_train = np.argmax(trainy, axis= 1)
    #y_train = np.argmax(trainy, axis=-1)
    
    print("Train accuracy Score------------>")
    print ("{0:.3f}".format(accuracy_score(y_train, y_pred_train)*100), "%")
    
    print("Val accuracy Score--------->")
    
    print("{0:.3f}".format(accuracy_score(y_val, y_pred_val)*100), "%")
    

    
  
    print("Test accuracy Score--------->")
    print("{0:.3f}".format(accuracy_score(y_test, y_pred_test)*100), "%")
    
    print("F1 Score--------------->")
    print("{0:.3f}".format(f1_score(y_test, y_pred_test, average = 'weighted')*100), "%")
    
    print("Cohen Kappa Score------------->")
    print("{0:.3f}".format(cohen_kappa_score(y_test, y_pred_test)*100), "%")
    
    print("Recall-------------->")
    print("{0:.3f}".format(recall_score(y_test, y_pred_test, average = 'weighted')*100), "%")
    
    print("Precision-------------->")
    print("{0:.3f}".format(precision_score(y_test, y_pred_test, average = 'weighted')*100), "%")
    
    cf_matrix_test = confusion_matrix(y_test, y_pred_test)
    cf_matrix_val = confusion_matrix(y_val, y_pred_val)
    
    plt.figure(figsize = (12, 6))
    plt.subplot(121)
    sns.heatmap(cf_matrix_val, annot=True, cmap='Blues')
    plt.title("Val Confusion matrix")
    
    plt.subplot(122)
    sns.heatmap(cf_matrix_test, annot=True, cmap='Blues')
    plt.title("Test Confusion matrix")
    
    plt.show()
    
    
    return

# %% [markdown]
# # One Hot Encoding the labels

# %% [markdown]
# # ImageDataGenerator

# %%
from keras.preprocessing.image import ImageDataGenerator
from keras.callbacks import ModelCheckpoint
from keras.models import load_model
from keras.callbacks import *


#train_datagen2 = ImageDataGenerator(rescale = 1/255)

train_datagen = ImageDataGenerator(rescale = 1/255,
                                  width_shift_range = 0.1,
                                  height_shift_range = 0.1,
                                  fill_mode = 'constant',
                                  zoom_range = 0.1,
                                  rotation_range = 20)

val_datagen = ImageDataGenerator(rescale = 1/255)
val2_datagen = ImageDataGenerator(rescale = 1/255)

train_generator = train_datagen.flow(train_data,
                                     train_label, 
                                     batch_size = 16, 
                                     shuffle = False)

val_generator = val_datagen.flow(test_data,
                                 test_label,
                                 batch_size = 16,
                                 shuffle = False)
val2_generator = val_datagen.flow(val_data,
                                 val_label,
                                 batch_size = 16,
                                 shuffle = False)

# %% [markdown]
# # Vizualization After Augmentation

# %%
#get the first patch for visualization
images, labels = train_generator.next()

# %%
#get the augmented data
#train_data1=np.concatenate([train_generator.next()[0] for i in range(train_generator.__len__())])
train_label1=np.concatenate([train_generator.next()[1] for i in range(train_generator.__len__())])
#print(train_data1.shape)
print(train_label1.shape)
#print(y)
# Out:
# (110300, 2)

# %%
n_row = 3
n_col = 5

fig, ax = plt.subplots(n_row, n_col, figsize = (n_col*3, n_row*3), constrained_layout = True)

for row in tqdm(range(n_row)):
    
    for col in range(n_col):
        
        ax[row][col].imshow(images[row*n_col + col,:,:,0], cmap = 'bone')
        ax[row][col].set_xticks([])
        ax[row][col].set_yticks([])
# Out:
# 100%|██████████| 3/3 [00:00<00:00, 213.55it/s]

# %% [markdown]
# # Callback

# %%
#os.mkdir('Model')

# %%
#os.mkdir('History')
def get_callbacks():
    
#    filepath = './Model/best_model_multiclass_128.hdf5'
    filepath = 'best_model_multiclass_128.h5'
    callback1 = ModelCheckpoint(filepath, monitor='val_accuracy', verbose=1, save_best_only=True, mode='max')
    #callback1 = ModelCheckpoint(filepath, verbose=1, save_best_only=True, mode='min')
    callback2 = MyLogger(val_generator, 
                         y_test = np.argmax(test_label, axis = 1),
                         class_labels = ['idc-', 'idc+'])
    
    callback3 = CSVLogger('./History/Multiclass_Log_128.csv')

    return [callback1 ,callback2, callback3]

# %% [markdown]
# # Training

# %%
model = Network128(input_shape = (img_size, img_size, 3), nb_class = 2, depth = 5)
model.summary()
# Out:
# 2022-06-03 09:58:47.723600: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:937] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2022-06-03 09:58:47.855744: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:937] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2022-06-03 09:58:47.856570: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:937] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2022-06-03 09:58:47.857870: I tensorflow/core/platform/cpu_feature_guard.cc:142] This TensorFlow binary is optimized with oneAPI Deep Neural Network Library (oneDNN) to use the following CPU instructions in performance-critical operations:  AVX2 AVX512F FMA
# To enable them in other operations, rebuild TensorFlow with the appropriate compiler flags.
# 2022-06-03 09:58:47.858240: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:937] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2022-06-03 09:58:47.859237: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:937] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2022-06-03 09:58:47.860313: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:937] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2022-06-03 09:58:50.114671: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:937] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2022-06-03 09:58:50.115458: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:937] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2022-06-03 09:58:50.116133: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:937] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2022-06-03 09:58:50.117701: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1510] Created device /job:localhost/replica:0/task:0/device:GPU:0 with 15403 MB memory:  -> device: 0, name: Tesla P100-PCIE-16GB, pci bus id: 0000:00:04.0, compute capability: 6.0
# Model: "model"
# __________________________________________________________________________________________________
# Layer (type)                    Output Shape         Param #     Connected to
# ==================================================================================================
# input_1 (InputLayer)            [(None, 50, 50, 3)]  0
# __________________________________________________________________________________________________
# conv2d (Conv2D)                 (None, 50, 50, 16)   1216        input_1[0][0]
# __________________________________________________________________________________________________
# batch_normalization (BatchNorma (None, 50, 50, 16)   64          conv2d[0][0]
# __________________________________________________________________________________________________
# conv2d_1 (Conv2D)               (None, 25, 25, 32)   4640        batch_normalization[0][0]
# __________________________________________________________________________________________________
# batch_normalization_1 (BatchNor (None, 25, 25, 32)   128         conv2d_1[0][0]
# __________________________________________________________________________________________________
# conv2d_2 (Conv2D)               (None, 25, 25, 64)   2112        batch_normalization_1[0][0]
# __________________________________________________________________________________________________
# batch_normalization_2 (BatchNor (None, 25, 25, 64)   256         conv2d_2[0][0]
# __________________________________________________________________________________________________
# depthwise_conv2d (DepthwiseConv (None, 25, 25, 64)   640         batch_normalization_2[0][0]
# __________________________________________________________________________________________________
# depthwise_conv2d_1 (DepthwiseCo (None, 25, 25, 64)   640         batch_normalization_2[0][0]
# __________________________________________________________________________________________________
# depthwise_conv2d_2 (DepthwiseCo (None, 25, 25, 64)   640         batch_normalization_2[0][0]
# __________________________________________________________________________________________________
# depthwise_conv2d_3 (DepthwiseCo (None, 25, 25, 64)   640         batch_normalization_2[0][0]
# __________________________________________________________________________________________________
# depthwise_conv2d_4 (DepthwiseCo (None, 25, 25, 64)   640         batch_normalization_2[0][0]
# __________________________________________________________________________________________________
# batch_normalization_3 (BatchNor (None, 25, 25, 64)   256         depthwise_conv2d[0][0]
# __________________________________________________________________________________________________
# batch_normalization_4 (BatchNor (None, 25, 25, 64)   256         depthwise_conv2d_1[0][0]
# __________________________________________________________________________________________________
# batch_normalization_5 (BatchNor (None, 25, 25, 64)   256         depthwise_conv2d_2[0][0]
# __________________________________________________________________________________________________
# batch_normalization_6 (BatchNor (None, 25, 25, 64)   256         depthwise_conv2d_3[0][0]
# __________________________________________________________________________________________________
# batch_normalization_7 (BatchNor (None, 25, 25, 64)   256         depthwise_conv2d_4[0][0]
# __________________________________________________________________________________________________
# concatenate (Concatenate)       (None, 25, 25, 320)  0           batch_normalization_3[0][0]
#                                                                  batch_normalization_4[0][0]
#                                                                  batch_normalization_5[0][0]
#                                                                  batch_normalization_6[0][0]
#                                                                  batch_normalization_7[0][0]
# __________________________________________________________________________________________________
# conv2d_3 (Conv2D)               (None, 25, 25, 32)   10272       concatenate[0][0]
# __________________________________________________________________________________________________
# batch_normalization_8 (BatchNor (None, 25, 25, 32)   128         conv2d_3[0][0]
# __________________________________________________________________________________________________
# add (Add)                       (None, 25, 25, 32)   0           batch_normalization_8[0][0]
#                                                                  batch_normalization_1[0][0]
# __________________________________________________________________________________________________
# conv2d_4 (Conv2D)               (None, 25, 25, 64)   2112        add[0][0]
# __________________________________________________________________________________________________
# batch_normalization_9 (BatchNor (None, 25, 25, 64)   256         conv2d_4[0][0]
# __________________________________________________________________________________________________
# depthwise_conv2d_5 (DepthwiseCo (None, 25, 25, 64)   640         batch_normalization_9[0][0]
# __________________________________________________________________________________________________
# depthwise_conv2d_6 (DepthwiseCo (None, 25, 25, 64)   640         batch_normalization_9[0][0]
# __________________________________________________________________________________________________
# depthwise_conv2d_7 (DepthwiseCo (None, 25, 25, 64)   640         batch_normalization_9[0][0]
# __________________________________________________________________________________________________
# depthwise_conv2d_8 (DepthwiseCo (None, 25, 25, 64)   640         batch_normalization_9[0][0]
# __________________________________________________________________________________________________
# depthwise_conv2d_9 (DepthwiseCo (None, 25, 25, 64)   640         batch_normalization_9[0][0]
# __________________________________________________________________________________________________
# batch_normalization_10 (BatchNo (None, 25, 25, 64)   256         depthwise_conv2d_5[0][0]
# __________________________________________________________________________________________________
# batch_normalization_11 (BatchNo (None, 25, 25, 64)   256         depthwise_conv2d_6[0][0]
# __________________________________________________________________________________________________
# batch_normalization_12 (BatchNo (None, 25, 25, 64)   256         depthwise_conv2d_7[0][0]
# __________________________________________________________________________________________________
# batch_normalization_13 (BatchNo (None, 25, 25, 64)   256         depthwise_conv2d_8[0][0]
# __________________________________________________________________________________________________
# batch_normalization_14 (BatchNo (None, 25, 25, 64)   256         depthwise_conv2d_9[0][0]
# __________________________________________________________________________________________________
# concatenate_1 (Concatenate)     (None, 25, 25, 320)  0           batch_normalization_10[0][0]
#                                                                  batch_normalization_11[0][0]
#                                                                  batch_normalization_12[0][0]
#                                                                  batch_normalization_13[0][0]
#                                                                  batch_normalization_14[0][0]
# __________________________________________________________________________________________________
# conv2d_5 (Conv2D)               (None, 25, 25, 32)   10272       concatenate_1[0][0]
# __________________________________________________________________________________________________
# batch_normalization_15 (BatchNo (None, 25, 25, 32)   128         conv2d_5[0][0]
# __________________________________________________________________________________________________
# add_1 (Add)                     (None, 25, 25, 32)   0           batch_normalization_15[0][0]
#                                                                  add[0][0]
# __________________________________________________________________________________________________
# conv2d_6 (Conv2D)               (None, 25, 25, 64)   2112        add_1[0][0]
# __________________________________________________________________________________________________
# batch_normalization_16 (BatchNo (None, 25, 25, 64)   256         conv2d_6[0][0]
# __________________________________________________________________________________________________
# depthwise_conv2d_10 (DepthwiseC (None, 25, 25, 64)   640         batch_normalization_16[0][0]
# __________________________________________________________________________________________________
# depthwise_conv2d_11 (DepthwiseC (None, 25, 25, 64)   640         batch_normalization_16[0][0]
# __________________________________________________________________________________________________
# depthwise_conv2d_12 (DepthwiseC (None, 25, 25, 64)   640         batch_normalization_16[0][0]
# __________________________________________________________________________________________________
# depthwise_conv2d_13 (DepthwiseC (None, 25, 25, 64)   640         batch_normalization_16[0][0]
# __________________________________________________________________________________________________
# depthwise_conv2d_14 (DepthwiseC (None, 25, 25, 64)   640         batch_normalization_16[0][0]
# __________________________________________________________________________________________________
# batch_normalization_17 (BatchNo (None, 25, 25, 64)   256         depthwise_conv2d_10[0][0]
# __________________________________________________________________________________________________
# batch_normalization_18 (BatchNo (None, 25, 25, 64)   256         depthwise_conv2d_11[0][0]
# __________________________________________________________________________________________________
# batch_normalization_19 (BatchNo (None, 25, 25, 64)   256         depthwise_conv2d_12[0][0]
# __________________________________________________________________________________________________
# batch_normalization_20 (BatchNo (None, 25, 25, 64)   256         depthwise_conv2d_13[0][0]
# __________________________________________________________________________________________________
# batch_normalization_21 (BatchNo (None, 25, 25, 64)   256         depthwise_conv2d_14[0][0]
# __________________________________________________________________________________________________
# concatenate_2 (Concatenate)     (None, 25, 25, 320)  0           batch_normalization_17[0][0]
#                                                                  batch_normalization_18[0][0]
#                                                                  batch_normalization_19[0][0]
#                                                                  batch_normalization_20[0][0]
#                                                                  batch_normalization_21[0][0]
# __________________________________________________________________________________________________
# conv2d_7 (Conv2D)               (None, 25, 25, 32)   10272       concatenate_2[0][0]
# __________________________________________________________________________________________________
# batch_normalization_22 (BatchNo (None, 25, 25, 32)   128         conv2d_7[0][0]
# __________________________________________________________________________________________________
# add_2 (Add)                     (None, 25, 25, 32)   0           batch_normalization_22[0][0]
#                                                                  add_1[0][0]
# __________________________________________________________________________________________________
# conv2d_8 (Conv2D)               (None, 25, 25, 64)   2112        add_2[0][0]
# __________________________________________________________________________________________________
# batch_normalization_23 (BatchNo (None, 25, 25, 64)   256         conv2d_8[0][0]
# __________________________________________________________________________________________________
# depthwise_conv2d_15 (DepthwiseC (None, 25, 25, 64)   640         batch_normalization_23[0][0]
# __________________________________________________________________________________________________
# depthwise_conv2d_16 (DepthwiseC (None, 25, 25, 64)   640         batch_normalization_23[0][0]
# __________________________________________________________________________________________________
# depthwise_conv2d_17 (DepthwiseC (None, 25, 25, 64)   640         batch_normalization_23[0][0]
# __________________________________________________________________________________________________
# depthwise_conv2d_18 (DepthwiseC (None, 25, 25, 64)   640         batch_normalization_23[0][0]
# __________________________________________________________________________________________________
# depthwise_conv2d_19 (DepthwiseC (None, 25, 25, 64)   640         batch_normalization_23[0][0]
# __________________________________________________________________________________________________
# batch_normalization_24 (BatchNo (None, 25, 25, 64)   256         depthwise_conv2d_15[0][0]
# __________________________________________________________________________________________________
# batch_normalization_25 (BatchNo (None, 25, 25, 64)   256         depthwise_conv2d_16[0][0]
# __________________________________________________________________________________________________
# batch_normalization_26 (BatchNo (None, 25, 25, 64)   256         depthwise_conv2d_17[0][0]
# __________________________________________________________________________________________________
# batch_normalization_27 (BatchNo (None, 25, 25, 64)   256         depthwise_conv2d_18[0][0]
# __________________________________________________________________________________________________
# batch_normalization_28 (BatchNo (None, 25, 25, 64)   256         depthwise_conv2d_19[0][0]
# __________________________________________________________________________________________________
# concatenate_3 (Concatenate)     (None, 25, 25, 320)  0           batch_normalization_24[0][0]
#                                                                  batch_normalization_25[0][0]
#                                                                  batch_normalization_26[0][0]
#                                                                  batch_normalization_27[0][0]
#                                                                  batch_normalization_28[0][0]
# __________________________________________________________________________________________________
# conv2d_9 (Conv2D)               (None, 25, 25, 32)   10272       concatenate_3[0][0]
# __________________________________________________________________________________________________
# batch_normalization_29 (BatchNo (None, 25, 25, 32)   128         conv2d_9[0][0]
# __________________________________________________________________________________________________
# add_3 (Add)                     (None, 25, 25, 32)   0           batch_normalization_29[0][0]
#                                                                  add_2[0][0]
# __________________________________________________________________________________________________
# conv2d_10 (Conv2D)              (None, 25, 25, 64)   2112        add_3[0][0]
# __________________________________________________________________________________________________
# batch_normalization_30 (BatchNo (None, 25, 25, 64)   256         conv2d_10[0][0]
# __________________________________________________________________________________________________
# depthwise_conv2d_20 (DepthwiseC (None, 25, 25, 64)   640         batch_normalization_30[0][0]
# __________________________________________________________________________________________________
# depthwise_conv2d_21 (DepthwiseC (None, 25, 25, 64)   640         batch_normalization_30[0][0]
# __________________________________________________________________________________________________
# depthwise_conv2d_22 (DepthwiseC (None, 25, 25, 64)   640         batch_normalization_30[0][0]
# __________________________________________________________________________________________________
# depthwise_conv2d_23 (DepthwiseC (None, 25, 25, 64)   640         batch_normalization_30[0][0]
# __________________________________________________________________________________________________
# depthwise_conv2d_24 (DepthwiseC (None, 25, 25, 64)   640         batch_normalization_30[0][0]
# __________________________________________________________________________________________________
# batch_normalization_31 (BatchNo (None, 25, 25, 64)   256         depthwise_conv2d_20[0][0]
# __________________________________________________________________________________________________
# batch_normalization_32 (BatchNo (None, 25, 25, 64)   256         depthwise_conv2d_21[0][0]
# __________________________________________________________________________________________________
# batch_normalization_33 (BatchNo (None, 25, 25, 64)   256         depthwise_conv2d_22[0][0]
# __________________________________________________________________________________________________
# batch_normalization_34 (BatchNo (None, 25, 25, 64)   256         depthwise_conv2d_23[0][0]
# __________________________________________________________________________________________________
# batch_normalization_35 (BatchNo (None, 25, 25, 64)   256         depthwise_conv2d_24[0][0]
# __________________________________________________________________________________________________
# concatenate_4 (Concatenate)     (None, 25, 25, 320)  0           batch_normalization_31[0][0]
#                                                                  batch_normalization_32[0][0]
#                                                                  batch_normalization_33[0][0]
#                                                                  batch_normalization_34[0][0]
#                                                                  batch_normalization_35[0][0]
# __________________________________________________________________________________________________
# conv2d_11 (Conv2D)              (None, 25, 25, 32)   10272       concatenate_4[0][0]
# __________________________________________________________________________________________________
# batch_normalization_36 (BatchNo (None, 25, 25, 32)   128         conv2d_11[0][0]
# __________________________________________________________________________________________________
# add_4 (Add)                     (None, 25, 25, 32)   0           batch_normalization_36[0][0]
#                                                                  add_3[0][0]
# __________________________________________________________________________________________________
# conv2d_12 (Conv2D)              (None, 25, 25, 128)  4224        add_4[0][0]
# __________________________________________________________________________________________________
# batch_normalization_37 (BatchNo (None, 25, 25, 128)  512         conv2d_12[0][0]
# __________________________________________________________________________________________________
# depthwise_conv2d_25 (DepthwiseC (None, 25, 25, 128)  1280        batch_normalization_37[0][0]
# __________________________________________________________________________________________________
# depthwise_conv2d_26 (DepthwiseC (None, 25, 25, 128)  1280        batch_normalization_37[0][0]
# __________________________________________________________________________________________________
# depthwise_conv2d_27 (DepthwiseC (None, 25, 25, 128)  1280        batch_normalization_37[0][0]
# __________________________________________________________________________________________________
# depthwise_conv2d_28 (DepthwiseC (None, 25, 25, 128)  1280        batch_normalization_37[0][0]
# __________________________________________________________________________________________________
# depthwise_conv2d_29 (DepthwiseC (None, 25, 25, 128)  1280        batch_normalization_37[0][0]
# __________________________________________________________________________________________________
# max_pooling2d (MaxPooling2D)    (None, 12, 12, 128)  0           depthwise_conv2d_25[0][0]
# __________________________________________________________________________________________________
# max_pooling2d_1 (MaxPooling2D)  (None, 12, 12, 128)  0           depthwise_conv2d_26[0][0]
# __________________________________________________________________________________________________
# max_pooling2d_2 (MaxPooling2D)  (None, 12, 12, 128)  0           depthwise_conv2d_27[0][0]
# __________________________________________________________________________________________________
# max_pooling2d_3 (MaxPooling2D)  (None, 12, 12, 128)  0           depthwise_conv2d_28[0][0]
# __________________________________________________________________________________________________
# max_pooling2d_4 (MaxPooling2D)  (None, 12, 12, 128)  0           depthwise_conv2d_29[0][0]
# __________________________________________________________________________________________________
# batch_normalization_38 (BatchNo (None, 12, 12, 128)  512         max_pooling2d[0][0]
# __________________________________________________________________________________________________
# batch_normalization_39 (BatchNo (None, 12, 12, 128)  512         max_pooling2d_1[0][0]
# __________________________________________________________________________________________________
# batch_normalization_40 (BatchNo (None, 12, 12, 128)  512         max_pooling2d_2[0][0]
# __________________________________________________________________________________________________
# batch_normalization_41 (BatchNo (None, 12, 12, 128)  512         max_pooling2d_3[0][0]
# __________________________________________________________________________________________________
# batch_normalization_42 (BatchNo (None, 12, 12, 128)  512         max_pooling2d_4[0][0]
# __________________________________________________________________________________________________
# concatenate_5 (Concatenate)     (None, 12, 12, 640)  0           batch_normalization_38[0][0]
#                                                                  batch_normalization_39[0][0]
#                                                                  batch_normalization_40[0][0]
#                                                                  batch_normalization_41[0][0]
#                                                                  batch_normalization_42[0][0]
# __________________________________________________________________________________________________
# conv2d_13 (Conv2D)              (None, 12, 12, 64)   41024       concatenate_5[0][0]
# __________________________________________________________________________________________________
# batch_normalization_43 (BatchNo (None, 12, 12, 64)   256         conv2d_13[0][0]
# __________________________________________________________________________________________________
# conv2d_14 (Conv2D)              (None, 12, 12, 128)  8320        batch_normalization_43[0][0]
# __________________________________________________________________________________________________
# batch_normalization_44 (BatchNo (None, 12, 12, 128)  512         conv2d_14[0][0]
# __________________________________________________________________________________________________
# depthwise_conv2d_30 (DepthwiseC (None, 12, 12, 128)  1280        batch_normalization_44[0][0]
# __________________________________________________________________________________________________
# depthwise_conv2d_31 (DepthwiseC (None, 12, 12, 128)  1280        batch_normalization_44[0][0]
# __________________________________________________________________________________________________
# depthwise_conv2d_32 (DepthwiseC (None, 12, 12, 128)  1280        batch_normalization_44[0][0]
# __________________________________________________________________________________________________
# depthwise_conv2d_33 (DepthwiseC (None, 12, 12, 128)  1280        batch_normalization_44[0][0]
# __________________________________________________________________________________________________
# batch_normalization_45 (BatchNo (None, 12, 12, 128)  512         depthwise_conv2d_30[0][0]
# __________________________________________________________________________________________________
# batch_normalization_46 (BatchNo (None, 12, 12, 128)  512         depthwise_conv2d_31[0][0]
# __________________________________________________________________________________________________
# batch_normalization_47 (BatchNo (None, 12, 12, 128)  512         depthwise_conv2d_32[0][0]
# __________________________________________________________________________________________________
# batch_normalization_48 (BatchNo (None, 12, 12, 128)  512         depthwise_conv2d_33[0][0]
# __________________________________________________________________________________________________
# concatenate_6 (Concatenate)     (None, 12, 12, 512)  0           batch_normalization_45[0][0]
#                                                                  batch_normalization_46[0][0]
#                                                                  batch_normalization_47[0][0]
#                                                                  batch_normalization_48[0][0]
# __________________________________________________________________________________________________
# conv2d_15 (Conv2D)              (None, 12, 12, 64)   32832       concatenate_6[0][0]
# __________________________________________________________________________________________________
# batch_normalization_49 (BatchNo (None, 12, 12, 64)   256         conv2d_15[0][0]
# __________________________________________________________________________________________________
# add_5 (Add)                     (None, 12, 12, 64)   0           batch_normalization_49[0][0]
#                                                                  batch_normalization_43[0][0]
# __________________________________________________________________________________________________
# conv2d_16 (Conv2D)              (None, 12, 12, 128)  8320        add_5[0][0]
# __________________________________________________________________________________________________
# batch_normalization_50 (BatchNo (None, 12, 12, 128)  512         conv2d_16[0][0]
# __________________________________________________________________________________________________
# depthwise_conv2d_34 (DepthwiseC (None, 12, 12, 128)  1280        batch_normalization_50[0][0]
# __________________________________________________________________________________________________
# depthwise_conv2d_35 (DepthwiseC (None, 12, 12, 128)  1280        batch_normalization_50[0][0]
# __________________________________________________________________________________________________
# depthwise_conv2d_36 (DepthwiseC (None, 12, 12, 128)  1280        batch_normalization_50[0][0]
# __________________________________________________________________________________________________
# depthwise_conv2d_37 (DepthwiseC (None, 12, 12, 128)  1280        batch_normalization_50[0][0]
# __________________________________________________________________________________________________
# batch_normalization_51 (BatchNo (None, 12, 12, 128)  512         depthwise_conv2d_34[0][0]
# __________________________________________________________________________________________________
# batch_normalization_52 (BatchNo (None, 12, 12, 128)  512         depthwise_conv2d_35[0][0]
# __________________________________________________________________________________________________
# batch_normalization_53 (BatchNo (None, 12, 12, 128)  512         depthwise_conv2d_36[0][0]
# __________________________________________________________________________________________________
# batch_normalization_54 (BatchNo (None, 12, 12, 128)  512         depthwise_conv2d_37[0][0]
# __________________________________________________________________________________________________
# concatenate_7 (Concatenate)     (None, 12, 12, 512)  0           batch_normalization_51[0][0]
#                                                                  batch_normalization_52[0][0]
#                                                                  batch_normalization_53[0][0]
#                                                                  batch_normalization_54[0][0]
# __________________________________________________________________________________________________
# conv2d_17 (Conv2D)              (None, 12, 12, 64)   32832       concatenate_7[0][0]
# __________________________________________________________________________________________________
# batch_normalization_55 (BatchNo (None, 12, 12, 64)   256         conv2d_17[0][0]
# __________________________________________________________________________________________________
# add_6 (Add)                     (None, 12, 12, 64)   0           batch_normalization_55[0][0]
#                                                                  add_5[0][0]
# __________________________________________________________________________________________________
# conv2d_18 (Conv2D)              (None, 12, 12, 128)  8320        add_6[0][0]
# __________________________________________________________________________________________________
# batch_normalization_56 (BatchNo (None, 12, 12, 128)  512         conv2d_18[0][0]
# __________________________________________________________________________________________________
# depthwise_conv2d_38 (DepthwiseC (None, 12, 12, 128)  1280        batch_normalization_56[0][0]
# __________________________________________________________________________________________________
# depthwise_conv2d_39 (DepthwiseC (None, 12, 12, 128)  1280        batch_normalization_56[0][0]
# __________________________________________________________________________________________________
# depthwise_conv2d_40 (DepthwiseC (None, 12, 12, 128)  1280        batch_normalization_56[0][0]
# __________________________________________________________________________________________________
# depthwise_conv2d_41 (DepthwiseC (None, 12, 12, 128)  1280        batch_normalization_56[0][0]
# __________________________________________________________________________________________________
# batch_normalization_57 (BatchNo (None, 12, 12, 128)  512         depthwise_conv2d_38[0][0]
# __________________________________________________________________________________________________
# batch_normalization_58 (BatchNo (None, 12, 12, 128)  512         depthwise_conv2d_39[0][0]
# __________________________________________________________________________________________________
# batch_normalization_59 (BatchNo (None, 12, 12, 128)  512         depthwise_conv2d_40[0][0]
# __________________________________________________________________________________________________
# batch_normalization_60 (BatchNo (None, 12, 12, 128)  512         depthwise_conv2d_41[0][0]
# __________________________________________________________________________________________________
# concatenate_8 (Concatenate)     (None, 12, 12, 512)  0           batch_normalization_57[0][0]
#                                                                  batch_normalization_58[0][0]
#                                                                  batch_normalization_59[0][0]
#                                                                  batch_normalization_60[0][0]
# __________________________________________________________________________________________________
# conv2d_19 (Conv2D)              (None, 12, 12, 64)   32832       concatenate_8[0][0]
# __________________________________________________________________________________________________
# batch_normalization_61 (BatchNo (None, 12, 12, 64)   256         conv2d_19[0][0]
# __________________________________________________________________________________________________
# add_7 (Add)                     (None, 12, 12, 64)   0           batch_normalization_61[0][0]
#                                                                  add_6[0][0]
# __________________________________________________________________________________________________
# conv2d_20 (Conv2D)              (None, 12, 12, 128)  8320        add_7[0][0]
# __________________________________________________________________________________________________
# batch_normalization_62 (BatchNo (None, 12, 12, 128)  512         conv2d_20[0][0]
# __________________________________________________________________________________________________
# depthwise_conv2d_42 (DepthwiseC (None, 12, 12, 128)  1280        batch_normalization_62[0][0]
# __________________________________________________________________________________________________
# depthwise_conv2d_43 (DepthwiseC (None, 12, 12, 128)  1280        batch_normalization_62[0][0]
# __________________________________________________________________________________________________
# depthwise_conv2d_44 (DepthwiseC (None, 12, 12, 128)  1280        batch_normalization_62[0][0]
# __________________________________________________________________________________________________
# depthwise_conv2d_45 (DepthwiseC (None, 12, 12, 128)  1280        batch_normalization_62[0][0]
# __________________________________________________________________________________________________
# batch_normalization_63 (BatchNo (None, 12, 12, 128)  512         depthwise_conv2d_42[0][0]
# __________________________________________________________________________________________________
# batch_normalization_64 (BatchNo (None, 12, 12, 128)  512         depthwise_conv2d_43[0][0]
# __________________________________________________________________________________________________
# batch_normalization_65 (BatchNo (None, 12, 12, 128)  512         depthwise_conv2d_44[0][0]
# __________________________________________________________________________________________________
# batch_normalization_66 (BatchNo (None, 12, 12, 128)  512         depthwise_conv2d_45[0][0]
# __________________________________________________________________________________________________
# concatenate_9 (Concatenate)     (None, 12, 12, 512)  0           batch_normalization_63[0][0]
#                                                                  batch_normalization_64[0][0]
#                                                                  batch_normalization_65[0][0]
#                                                                  batch_normalization_66[0][0]
# __________________________________________________________________________________________________
# conv2d_21 (Conv2D)              (None, 12, 12, 64)   32832       concatenate_9[0][0]
# __________________________________________________________________________________________________
# batch_normalization_67 (BatchNo (None, 12, 12, 64)   256         conv2d_21[0][0]
# __________________________________________________________________________________________________
# add_8 (Add)                     (None, 12, 12, 64)   0           batch_normalization_67[0][0]
#                                                                  add_7[0][0]
# __________________________________________________________________________________________________
# conv2d_22 (Conv2D)              (None, 12, 12, 128)  8320        add_8[0][0]
# __________________________________________________________________________________________________
# batch_normalization_68 (BatchNo (None, 12, 12, 128)  512         conv2d_22[0][0]
# __________________________________________________________________________________________________
# depthwise_conv2d_46 (DepthwiseC (None, 12, 12, 128)  1280        batch_normalization_68[0][0]
# __________________________________________________________________________________________________
# depthwise_conv2d_47 (DepthwiseC (None, 12, 12, 128)  1280        batch_normalization_68[0][0]
# __________________________________________________________________________________________________
# depthwise_conv2d_48 (DepthwiseC (None, 12, 12, 128)  1280        batch_normalization_68[0][0]
# __________________________________________________________________________________________________
# depthwise_conv2d_49 (DepthwiseC (None, 12, 12, 128)  1280        batch_normalization_68[0][0]
# __________________________________________________________________________________________________
# batch_normalization_69 (BatchNo (None, 12, 12, 128)  512         depthwise_conv2d_46[0][0]
# __________________________________________________________________________________________________
# batch_normalization_70 (BatchNo (None, 12, 12, 128)  512         depthwise_conv2d_47[0][0]
# __________________________________________________________________________________________________
# batch_normalization_71 (BatchNo (None, 12, 12, 128)  512         depthwise_conv2d_48[0][0]
# __________________________________________________________________________________________________
# batch_normalization_72 (BatchNo (None, 12, 12, 128)  512         depthwise_conv2d_49[0][0]
# __________________________________________________________________________________________________
# concatenate_10 (Concatenate)    (None, 12, 12, 512)  0           batch_normalization_69[0][0]
#                                                                  batch_normalization_70[0][0]
#                                                                  batch_normalization_71[0][0]
#                                                                  batch_normalization_72[0][0]
# __________________________________________________________________________________________________
# conv2d_23 (Conv2D)              (None, 12, 12, 64)   32832       concatenate_10[0][0]
# __________________________________________________________________________________________________
# batch_normalization_73 (BatchNo (None, 12, 12, 64)   256         conv2d_23[0][0]
# __________________________________________________________________________________________________
# add_9 (Add)                     (None, 12, 12, 64)   0           batch_normalization_73[0][0]
#                                                                  add_8[0][0]
# __________________________________________________________________________________________________
# conv2d_24 (Conv2D)              (None, 12, 12, 256)  16640       add_9[0][0]
# __________________________________________________________________________________________________
# batch_normalization_74 (BatchNo (None, 12, 12, 256)  1024        conv2d_24[0][0]
# __________________________________________________________________________________________________
# depthwise_conv2d_50 (DepthwiseC (None, 12, 12, 256)  2560        batch_normalization_74[0][0]
# __________________________________________________________________________________________________
# depthwise_conv2d_51 (DepthwiseC (None, 12, 12, 256)  2560        batch_normalization_74[0][0]
# __________________________________________________________________________________________________
# depthwise_conv2d_52 (DepthwiseC (None, 12, 12, 256)  2560        batch_normalization_74[0][0]
# __________________________________________________________________________________________________
# depthwise_conv2d_53 (DepthwiseC (None, 12, 12, 256)  2560        batch_normalization_74[0][0]
# __________________________________________________________________________________________________
# max_pooling2d_5 (MaxPooling2D)  (None, 6, 6, 256)    0           depthwise_conv2d_50[0][0]
# __________________________________________________________________________________________________
# max_pooling2d_6 (MaxPooling2D)  (None, 6, 6, 256)    0           depthwise_conv2d_51[0][0]
# __________________________________________________________________________________________________
# max_pooling2d_7 (MaxPooling2D)  (None, 6, 6, 256)    0           depthwise_conv2d_52[0][0]
# __________________________________________________________________________________________________
# max_pooling2d_8 (MaxPooling2D)  (None, 6, 6, 256)    0           depthwise_conv2d_53[0][0]
# __________________________________________________________________________________________________
# batch_normalization_75 (BatchNo (None, 6, 6, 256)    1024        max_pooling2d_5[0][0]
# __________________________________________________________________________________________________
# batch_normalization_76 (BatchNo (None, 6, 6, 256)    1024        max_pooling2d_6[0][0]
# __________________________________________________________________________________________________
# batch_normalization_77 (BatchNo (None, 6, 6, 256)    1024        max_pooling2d_7[0][0]
# __________________________________________________________________________________________________
# batch_normalization_78 (BatchNo (None, 6, 6, 256)    1024        max_pooling2d_8[0][0]
# __________________________________________________________________________________________________
# concatenate_11 (Concatenate)    (None, 6, 6, 1024)   0           batch_normalization_75[0][0]
#                                                                  batch_normalization_76[0][0]
#                                                                  batch_normalization_77[0][0]
#                                                                  batch_normalization_78[0][0]
# __________________________________________________________________________________________________
# conv2d_25 (Conv2D)              (None, 6, 6, 128)    131200      concatenate_11[0][0]
# __________________________________________________________________________________________________
# batch_normalization_79 (BatchNo (None, 6, 6, 128)    512         conv2d_25[0][0]
# __________________________________________________________________________________________________
# conv2d_26 (Conv2D)              (None, 6, 6, 256)    33024       batch_normalization_79[0][0]
# __________________________________________________________________________________________________
# batch_normalization_80 (BatchNo (None, 6, 6, 256)    1024        conv2d_26[0][0]
# __________________________________________________________________________________________________
# depthwise_conv2d_54 (DepthwiseC (None, 6, 6, 256)    2560        batch_normalization_80[0][0]
# __________________________________________________________________________________________________
# depthwise_conv2d_55 (DepthwiseC (None, 6, 6, 256)    2560        batch_normalization_80[0][0]
# __________________________________________________________________________________________________
# depthwise_conv2d_56 (DepthwiseC (None, 6, 6, 256)    2560        batch_normalization_80[0][0]
# __________________________________________________________________________________________________
# batch_normalization_81 (BatchNo (None, 6, 6, 256)    1024        depthwise_conv2d_54[0][0]
# __________________________________________________________________________________________________
# batch_normalization_82 (BatchNo (None, 6, 6, 256)    1024        depthwise_conv2d_55[0][0]
# __________________________________________________________________________________________________
# batch_normalization_83 (BatchNo (None, 6, 6, 256)    1024        depthwise_conv2d_56[0][0]
# __________________________________________________________________________________________________
# concatenate_12 (Concatenate)    (None, 6, 6, 768)    0           batch_normalization_81[0][0]
#                                                                  batch_normalization_82[0][0]
#                                                                  batch_normalization_83[0][0]
# ...
# concatenate_16 (Concatenate)    (None, 6, 6, 768)    0           batch_normalization_101[0][0]
#                                                                  batch_normalization_102[0][0]
#                                                                  batch_normalization_103[0][0]
# __________________________________________________________________________________________________
# conv2d_35 (Conv2D)              (None, 6, 6, 128)    98432       concatenate_16[0][0]
# __________________________________________________________________________________________________
# batch_normalization_104 (BatchN (None, 6, 6, 128)    512         conv2d_35[0][0]
# __________________________________________________________________________________________________
# add_14 (Add)                    (None, 6, 6, 128)    0           batch_normalization_104[0][0]
#                                                                  add_13[0][0]
# __________________________________________________________________________________________________
# conv2d_36 (Conv2D)              (None, 6, 6, 512)    66048       add_14[0][0]
# __________________________________________________________________________________________________
# batch_normalization_105 (BatchN (None, 6, 6, 512)    2048        conv2d_36[0][0]
# __________________________________________________________________________________________________
# depthwise_conv2d_69 (DepthwiseC (None, 6, 6, 512)    5120        batch_normalization_105[0][0]
# __________________________________________________________________________________________________
# depthwise_conv2d_70 (DepthwiseC (None, 6, 6, 512)    5120        batch_normalization_105[0][0]
# __________________________________________________________________________________________________
# depthwise_conv2d_71 (DepthwiseC (None, 6, 6, 512)    5120        batch_normalization_105[0][0]
# __________________________________________________________________________________________________
# max_pooling2d_9 (MaxPooling2D)  (None, 3, 3, 512)    0           depthwise_conv2d_69[0][0]
# __________________________________________________________________________________________________
# max_pooling2d_10 (MaxPooling2D) (None, 3, 3, 512)    0           depthwise_conv2d_70[0][0]
# __________________________________________________________________________________________________
# max_pooling2d_11 (MaxPooling2D) (None, 3, 3, 512)    0           depthwise_conv2d_71[0][0]
# __________________________________________________________________________________________________
# batch_normalization_106 (BatchN (None, 3, 3, 512)    2048        max_pooling2d_9[0][0]
# __________________________________________________________________________________________________
# batch_normalization_107 (BatchN (None, 3, 3, 512)    2048        max_pooling2d_10[0][0]
# __________________________________________________________________________________________________
# batch_normalization_108 (BatchN (None, 3, 3, 512)    2048        max_pooling2d_11[0][0]
# __________________________________________________________________________________________________
# concatenate_17 (Concatenate)    (None, 3, 3, 1536)   0           batch_normalization_106[0][0]
#                                                                  batch_normalization_107[0][0]
#                                                                  batch_normalization_108[0][0]
# __________________________________________________________________________________________________
# conv2d_37 (Conv2D)              (None, 3, 3, 256)    393472      concatenate_17[0][0]
# __________________________________________________________________________________________________
# batch_normalization_109 (BatchN (None, 3, 3, 256)    1024        conv2d_37[0][0]
# __________________________________________________________________________________________________
# conv2d_38 (Conv2D)              (None, 3, 3, 512)    131584      batch_normalization_109[0][0]
# __________________________________________________________________________________________________
# batch_normalization_110 (BatchN (None, 3, 3, 512)    2048        conv2d_38[0][0]
# __________________________________________________________________________________________________
# depthwise_conv2d_72 (DepthwiseC (None, 3, 3, 512)    5120        batch_normalization_110[0][0]
# __________________________________________________________________________________________________
# depthwise_conv2d_73 (DepthwiseC (None, 3, 3, 512)    5120        batch_normalization_110[0][0]
# __________________________________________________________________________________________________
# batch_normalization_111 (BatchN (None, 3, 3, 512)    2048        depthwise_conv2d_72[0][0]
# __________________________________________________________________________________________________
# batch_normalization_112 (BatchN (None, 3, 3, 512)    2048        depthwise_conv2d_73[0][0]
# __________________________________________________________________________________________________
# concatenate_18 (Concatenate)    (None, 3, 3, 1024)   0           batch_normalization_111[0][0]
#                                                                  batch_normalization_112[0][0]
# __________________________________________________________________________________________________
# conv2d_39 (Conv2D)              (None, 3, 3, 256)    262400      concatenate_18[0][0]
# __________________________________________________________________________________________________
# batch_normalization_113 (BatchN (None, 3, 3, 256)    1024        conv2d_39[0][0]
# __________________________________________________________________________________________________
# add_15 (Add)                    (None, 3, 3, 256)    0           batch_normalization_113[0][0]
#                                                                  batch_normalization_109[0][0]
# __________________________________________________________________________________________________
# conv2d_40 (Conv2D)              (None, 3, 3, 512)    131584      add_15[0][0]
# __________________________________________________________________________________________________
# batch_normalization_114 (BatchN (None, 3, 3, 512)    2048        conv2d_40[0][0]
# __________________________________________________________________________________________________
# depthwise_conv2d_74 (DepthwiseC (None, 3, 3, 512)    5120        batch_normalization_114[0][0]
# __________________________________________________________________________________________________
# depthwise_conv2d_75 (DepthwiseC (None, 3, 3, 512)    5120        batch_normalization_114[0][0]
# __________________________________________________________________________________________________
# batch_normalization_115 (BatchN (None, 3, 3, 512)    2048        depthwise_conv2d_74[0][0]
# __________________________________________________________________________________________________
# batch_normalization_116 (BatchN (None, 3, 3, 512)    2048        depthwise_conv2d_75[0][0]
# __________________________________________________________________________________________________
# concatenate_19 (Concatenate)    (None, 3, 3, 1024)   0           batch_normalization_115[0][0]
#                                                                  batch_normalization_116[0][0]
# __________________________________________________________________________________________________
# conv2d_41 (Conv2D)              (None, 3, 3, 256)    262400      concatenate_19[0][0]
# __________________________________________________________________________________________________
# batch_normalization_117 (BatchN (None, 3, 3, 256)    1024        conv2d_41[0][0]
# __________________________________________________________________________________________________
# add_16 (Add)                    (None, 3, 3, 256)    0           batch_normalization_117[0][0]
#                                                                  add_15[0][0]
# __________________________________________________________________________________________________
# conv2d_42 (Conv2D)              (None, 3, 3, 512)    131584      add_16[0][0]
# __________________________________________________________________________________________________
# batch_normalization_118 (BatchN (None, 3, 3, 512)    2048        conv2d_42[0][0]
# __________________________________________________________________________________________________
# depthwise_conv2d_76 (DepthwiseC (None, 3, 3, 512)    5120        batch_normalization_118[0][0]
# __________________________________________________________________________________________________
# depthwise_conv2d_77 (DepthwiseC (None, 3, 3, 512)    5120        batch_normalization_118[0][0]
# __________________________________________________________________________________________________
# batch_normalization_119 (BatchN (None, 3, 3, 512)    2048        depthwise_conv2d_76[0][0]
# __________________________________________________________________________________________________
# batch_normalization_120 (BatchN (None, 3, 3, 512)    2048        depthwise_conv2d_77[0][0]
# __________________________________________________________________________________________________
# concatenate_20 (Concatenate)    (None, 3, 3, 1024)   0           batch_normalization_119[0][0]
#                                                                  batch_normalization_120[0][0]
# __________________________________________________________________________________________________
# conv2d_43 (Conv2D)              (None, 3, 3, 256)    262400      concatenate_20[0][0]
# __________________________________________________________________________________________________
# batch_normalization_121 (BatchN (None, 3, 3, 256)    1024        conv2d_43[0][0]
# __________________________________________________________________________________________________
# add_17 (Add)                    (None, 3, 3, 256)    0           batch_normalization_121[0][0]
#                                                                  add_16[0][0]
# __________________________________________________________________________________________________
# conv2d_44 (Conv2D)              (None, 3, 3, 512)    131584      add_17[0][0]
# __________________________________________________________________________________________________
# batch_normalization_122 (BatchN (None, 3, 3, 512)    2048        conv2d_44[0][0]
# __________________________________________________________________________________________________
# depthwise_conv2d_78 (DepthwiseC (None, 3, 3, 512)    5120        batch_normalization_122[0][0]
# __________________________________________________________________________________________________
# depthwise_conv2d_79 (DepthwiseC (None, 3, 3, 512)    5120        batch_normalization_122[0][0]
# __________________________________________________________________________________________________
# batch_normalization_123 (BatchN (None, 3, 3, 512)    2048        depthwise_conv2d_78[0][0]
# __________________________________________________________________________________________________
# batch_normalization_124 (BatchN (None, 3, 3, 512)    2048        depthwise_conv2d_79[0][0]
# __________________________________________________________________________________________________
# concatenate_21 (Concatenate)    (None, 3, 3, 1024)   0           batch_normalization_123[0][0]
#                                                                  batch_normalization_124[0][0]
# __________________________________________________________________________________________________
# conv2d_45 (Conv2D)              (None, 3, 3, 256)    262400      concatenate_21[0][0]
# __________________________________________________________________________________________________
# batch_normalization_125 (BatchN (None, 3, 3, 256)    1024        conv2d_45[0][0]
# __________________________________________________________________________________________________
# add_18 (Add)                    (None, 3, 3, 256)    0           batch_normalization_125[0][0]
#                                                                  add_17[0][0]
# __________________________________________________________________________________________________
# conv2d_46 (Conv2D)              (None, 3, 3, 512)    131584      add_18[0][0]
# __________________________________________________________________________________________________
# batch_normalization_126 (BatchN (None, 3, 3, 512)    2048        conv2d_46[0][0]
# __________________________________________________________________________________________________
# depthwise_conv2d_80 (DepthwiseC (None, 3, 3, 512)    5120        batch_normalization_126[0][0]
# __________________________________________________________________________________________________
# depthwise_conv2d_81 (DepthwiseC (None, 3, 3, 512)    5120        batch_normalization_126[0][0]
# __________________________________________________________________________________________________
# batch_normalization_127 (BatchN (None, 3, 3, 512)    2048        depthwise_conv2d_80[0][0]
# __________________________________________________________________________________________________
# batch_normalization_128 (BatchN (None, 3, 3, 512)    2048        depthwise_conv2d_81[0][0]
# __________________________________________________________________________________________________
# concatenate_22 (Concatenate)    (None, 3, 3, 1024)   0           batch_normalization_127[0][0]
#                                                                  batch_normalization_128[0][0]
# __________________________________________________________________________________________________
# conv2d_47 (Conv2D)              (None, 3, 3, 256)    262400      concatenate_22[0][0]
# __________________________________________________________________________________________________
# batch_normalization_129 (BatchN (None, 3, 3, 256)    1024        conv2d_47[0][0]
# __________________________________________________________________________________________________
# add_19 (Add)                    (None, 3, 3, 256)    0           batch_normalization_129[0][0]
#                                                                  add_18[0][0]
# __________________________________________________________________________________________________
# global_average_pooling2d (Globa (None, 256)          0           add_19[0][0]
# __________________________________________________________________________________________________
# dense (Dense)                   (None, 128)          32896       global_average_pooling2d[0][0]
# __________________________________________________________________________________________________
# dense_1 (Dense)                 (None, 64)           8256        dense[0][0]
# __________________________________________________________________________________________________
# dense_2 (Dense)                 (None, 2)            130         dense_1[0][0]
# ==================================================================================================
# Total params: 3,857,474
# Trainable params: 3,807,650
# Non-trainable params: 49,824
# __________________________________________________________________________________________________

# %% [markdown]
# # Plotting Model

# %%
#from tensorflow.keras.utils import plot_model
#plot_model(model, show_shapes=True)

# %%
'''
#using augmentation data
history = model.fit_generator(train_generator, 
                              steps_per_epoch = len(train_data) // 16,
                              validation_data=val_generator,
                              validation_steps= len(test_data)// 16,
                              class_weight =class_weights,
                              epochs = 70,
                              callbacks = get_callbacks(),
                              verbose = 1
                              )
#using raw data
history = model.fit_generator(train_data_label, 
                              steps_per_epoch = epoch_step,
                              validation_data=train_val_data,
                              epochs = 70,
                              validation_steps= val_step, 
                              class_weight =class_weights,
                              callbacks = get_callbacks(),
                              verbose = 1
                              )


epoch_step = (len(train_data) // 16)
print(epoch_step)
val_step=len(test_data)// 16
print(val_step)
train_val_data=(test_data, test_label)
#print(train_generator.shape)
train_data_label=(train_data,train_label)
#print(val_generator.shape)
#(self, generator, steps_per_epoch, epochs, verbose, callbacks, validation_data, validation_steps, validation_freq, class_weight, max_queue_size, workers, use_multiprocessing, shuffle, initial_epoch)

history = model.fit_generator( 
                        train_datagen.flow(train_data,train_label),
                        steps_per_epoch=epoch_step,
                        epochs = 70,
                        verbose = 1,
                        callbacks = get_callbacks(),
                        validation_data=(test_data,test_label),
                        validation_steps = val_step,
                        class_weight =weights
                        )

'''
#from keras.models import load_model
model.load_weights('../input/covxnet-saved-model/220602-cropnet-V2-1fold-augmentation-best_model_multiclass_128.h5')
print("load weight success")
model.trainable=True
history = model.fit_generator(train_generator,
                              steps_per_epoch = len(train_data) // 16,
                              validation_data=val_generator,
                              validation_steps= len(test_data)// 16,
                              epochs = epoch_4_test,
                              callbacks = get_callbacks(),
                              verbose = 1
                              )
# Out:
# load weight success
# Epoch 1/30
# 2022-06-03 09:58:54.546988: I tensorflow/compiler/mlir/mlir_graph_optimization_pass.cc:185] None of the MLIR Optimization Passes are enabled (registered 2)
# 2022-06-03 09:59:09.263996: I tensorflow/stream_executor/cuda/cuda_dnn.cc:369] Loaded cuDNN version 8005
# 6893/6893 [==============================] - 877s 124ms/step - loss: 0.2718 - accuracy: 0.8879 - val_loss: 0.2936 - val_accuracy: 0.8770
#
# Epoch 00001: val_accuracy improved from -inf to 0.87698, saving model to best_model_multiclass_128.h5
# Predicting test data
# 887/887 [==============================] - 21s 21ms/step
# Done
#
#
# testing time(HH:MM:SS:ms) - 0:00:21.167244
#
#
# ---------------------
# | Balanced Accuracy  |
# ---------------------
#
#     0.8769567056832606
#
#
# ---------------------
# |      Accuracy      |
# ---------------------
#
#     0.8769567056832605
#
#
# -------------------------
# | Classifiction Report |
# -------------------------
#               precision    recall  f1-score   support
#
#            0       0.90      0.84      0.87      7091
#            1       0.85      0.91      0.88      7091
#
#     accuracy                           0.88     14182
#    macro avg       0.88      0.88      0.88     14182
# weighted avg       0.88      0.88      0.88     14182
#
# --------------------
# | Confusion Matrix |
# --------------------
#
#  [[5988 1103]
#  [ 642 6449]]
# Epoch 2/30
# 6893/6893 [==============================] - 876s 127ms/step - loss: 0.2664 - accuracy: 0.8902 - val_loss: 0.3012 - val_accuracy: 0.8736
#
# Epoch 00002: val_accuracy did not improve from 0.87698
# Predicting test data
# 887/887 [==============================] - 19s 22ms/step
# Done
#
#
# testing time(HH:MM:SS:ms) - 0:00:19.213360
#
#
# ---------------------
# | Balanced Accuracy  |
# ---------------------
#
#     0.8736426456071076
#
#
# ---------------------
# |      Accuracy      |
# ---------------------
#
#     0.8736426456071076
#
#
# -------------------------
# | Classifiction Report |
# -------------------------
#               precision    recall  f1-score   support
#
#            0       0.90      0.85      0.87      7091
#            1       0.85      0.90      0.88      7091
#
#     accuracy                           0.87     14182
#    macro avg       0.87      0.87      0.87     14182
# weighted avg       0.87      0.87      0.87     14182
#
# --------------------
# | Confusion Matrix |
# --------------------
#
#  [[5993 1098]
#  [ 694 6397]]
# Epoch 3/30
# 6893/6893 [==============================] - 861s 125ms/step - loss: 0.2636 - accuracy: 0.8911 - val_loss: 0.3009 - val_accuracy: 0.8715
#
# Epoch 00003: val_accuracy did not improve from 0.87698
# Predicting test data
# 887/887 [==============================] - 20s 22ms/step
# Done
#
#
# testing time(HH:MM:SS:ms) - 0:00:20.927498
#
#
# ---------------------
# | Balanced Accuracy  |
# ---------------------
#
#     0.8715272881116909
#
#
# ---------------------
# |      Accuracy      |
# ---------------------
#
#     0.8715272881116909
#
#
# -------------------------
# | Classifiction Report |
# -------------------------
#               precision    recall  f1-score   support
#
#            0       0.91      0.83      0.87      7091
#            1       0.84      0.92      0.88      7091
#
#     accuracy                           0.87     14182
#    macro avg       0.87      0.87      0.87     14182
# weighted avg       0.87      0.87      0.87     14182
#
# --------------------
# | Confusion Matrix |
# --------------------
#
#  [[5866 1225]
#  [ 597 6494]]
# Epoch 4/30
# 6893/6893 [==============================] - 880s 128ms/step - loss: 0.2603 - accuracy: 0.8931 - val_loss: 0.2855 - val_accuracy: 0.8821
#
# Epoch 00004: val_accuracy improved from 0.87698 to 0.88212, saving model to best_model_multiclass_128.h5
# Predicting test data
# 887/887 [==============================] - 19s 21ms/step
# Done
#
#
# testing time(HH:MM:SS:ms) - 0:00:20.534520
#
#
# ---------------------
# | Balanced Accuracy  |
# ---------------------
#
#     0.8821745875052884
#
#
# ---------------------
# |      Accuracy      |
# ---------------------
#
#     0.8821745875052884
#
#
# -------------------------
# | Classifiction Report |
# -------------------------
#               precision    recall  f1-score   support
#
#            0       0.91      0.85      0.88      7091
#            1       0.86      0.91      0.89      7091
#
#     accuracy                           0.88     14182
#    macro avg       0.88      0.88      0.88     14182
# weighted avg       0.88      0.88      0.88     14182
#
# --------------------
# | Confusion Matrix |
# --------------------
#
#  [[6028 1063]
#  [ 608 6483]]
# Epoch 5/30
# 6893/6893 [==============================] - 884s 128ms/step - loss: 0.2578 - accuracy: 0.8941 - val_loss: 0.3033 - val_accuracy: 0.8813
#
# Epoch 00005: val_accuracy did not improve from 0.88212
# Predicting test data
# 887/887 [==============================] - 20s 23ms/step
# Done
#
#
# testing time(HH:MM:SS:ms) - 0:00:20.164275
#
#
# ---------------------
# | Balanced Accuracy  |
# ---------------------
#
#     0.8813989564236355
#
#
# ---------------------
# |      Accuracy      |
# ---------------------
#
#     0.8813989564236356
#
#
# -------------------------
# | Classifiction Report |
# -------------------------
#               precision    recall  f1-score   support
#
#            0       0.89      0.87      0.88      7091
#            1       0.87      0.90      0.88      7091
#
#     accuracy                           0.88     14182
#    macro avg       0.88      0.88      0.88     14182
# weighted avg       0.88      0.88      0.88     14182
#
# --------------------
# | Confusion Matrix |
# --------------------
#
#  [[6134  957]
#  [ 725 6366]]
# Epoch 6/30
# 6893/6893 [==============================] - 872s 127ms/step - loss: 0.2551 - accuracy: 0.8955 - val_loss: 0.3276 - val_accuracy: 0.8667
#
# Epoch 00006: val_accuracy did not improve from 0.88212
# Predicting test data
# 887/887 [==============================] - 20s 22ms/step
# Done
#
#
# testing time(HH:MM:SS:ms) - 0:00:19.974718
#
#
# ---------------------
# | Balanced Accuracy  |
# ---------------------
#
#     0.8667324777887463
#
#
# ---------------------
# |      Accuracy      |
# ---------------------
#
#     0.8667324777887463
#
#
# -------------------------
# | Classifiction Report |
# -------------------------
#               precision    recall  f1-score   support
#
#            0       0.90      0.82      0.86      7091
#            1       0.84      0.91      0.87      7091
#
#     accuracy                           0.87     14182
#    macro avg       0.87      0.87      0.87     14182
# weighted avg       0.87      0.87      0.87     14182
#
# --------------------
# | Confusion Matrix |
# --------------------
#
#  [[5830 1261]
#  [ 629 6462]]
# Epoch 7/30
# 6893/6893 [==============================] - 872s 127ms/step - loss: 0.2540 - accuracy: 0.8952 - val_loss: 0.3195 - val_accuracy: 0.8639
#
# Epoch 00007: val_accuracy did not improve from 0.88212
# Predicting test data
# 887/887 [==============================] - 20s 23ms/step
# Done
#
#
# testing time(HH:MM:SS:ms) - 0:00:20.364284
#
#
# ---------------------
# | Balanced Accuracy  |
# ---------------------
#
#     0.8639825130447045
#
#
# ---------------------
# |      Accuracy      |
# ---------------------
#
#     0.8639825130447045
#
#
# -------------------------
# | Classifiction Report |
# -------------------------
#               precision    recall  f1-score   support
#
#            0       0.91      0.81      0.86      7091
#            1       0.83      0.92      0.87      7091
#
#     accuracy                           0.86     14182
#    macro avg       0.87      0.86      0.86     14182
# weighted avg       0.87      0.86      0.86     14182
#
# --------------------
# | Confusion Matrix |
# --------------------
#
#  [[5723 1368]
#  [ 561 6530]]
# Epoch 8/30
# 6893/6893 [==============================] - 867s 126ms/step - loss: 0.2502 - accuracy: 0.8971 - val_loss: 0.2835 - val_accuracy: 0.8887
#
# Epoch 00008: val_accuracy improved from 0.88212 to 0.88869, saving model to best_model_multiclass_128.h5
# Predicting test data
# 887/887 [==============================] - 20s 22ms/step
# Done
#
#
# testing time(HH:MM:SS:ms) - 0:00:20.540802
#
#
# ---------------------
# | Balanced Accuracy  |
# ---------------------
#
#     0.8887321957410802
#
#
# ---------------------
# |      Accuracy      |
# ---------------------
#
#     0.8887321957410802
#
#
# -------------------------
# | Classifiction Report |
# -------------------------
#               precision    recall  f1-score   support
#
#            0       0.92      0.85      0.88      7091
#            1       0.86      0.93      0.89      7091
#
#     accuracy                           0.89     14182
#    macro avg       0.89      0.89      0.89     14182
# weighted avg       0.89      0.89      0.89     14182
#
# --------------------
# | Confusion Matrix |
# --------------------
#
#  [[6022 1069]
#  [ 509 6582]]
# Epoch 9/30
# 6893/6893 [==============================] - 848s 123ms/step - loss: 0.2480 - accuracy: 0.8972 - val_loss: 0.3190 - val_accuracy: 0.8723
#
# Epoch 00009: val_accuracy did not improve from 0.88869
# Predicting test data
# 887/887 [==============================] - 19s 22ms/step
# Done
#
#
# testing time(HH:MM:SS:ms) - 0:00:20.511219
#
#
# ---------------------
# | Balanced Accuracy  |
# ---------------------
#
#     0.8723734311098575
#
#
# ---------------------
# |      Accuracy      |
# ---------------------
#
#     0.8723734311098575
#
#
# -------------------------
# | Classifiction Report |
# -------------------------
#               precision    recall  f1-score   support
#
#            0       0.93      0.81      0.86      7091
#            1       0.83      0.93      0.88      7091
#
#     accuracy                           0.87     14182
#    macro avg       0.88      0.87      0.87     14182
# weighted avg       0.88      0.87      0.87     14182
#
# --------------------
# | Confusion Matrix |
# --------------------
#
#  [[5743 1348]
#  [ 462 6629]]
# Epoch 10/30
# 6893/6893 [==============================] - 841s 122ms/step - loss: 0.2453 - accuracy: 0.8987 - val_loss: 0.2694 - val_accuracy: 0.8871
#
# Epoch 00010: val_accuracy did not improve from 0.88869
# Predicting test data
# 887/887 [==============================] - 20s 23ms/step
# Done
#
#
# testing time(HH:MM:SS:ms) - 0:00:20.523110
#
#
# ---------------------
# | Balanced Accuracy  |
# ---------------------
#
#     0.8871104216612608
#
#
# ---------------------
# |      Accuracy      |
# ---------------------
#
#     0.8871104216612608
#
#
# -------------------------
# | Classifiction Report |
# -------------------------
#               precision    recall  f1-score   support
#
#            0       0.91      0.86      0.88      7091
#            1       0.86      0.92      0.89      7091
#
#     accuracy                           0.89     14182
#    macro avg       0.89      0.89      0.89     14182
# weighted avg       0.89      0.89      0.89     14182
#
# --------------------
# | Confusion Matrix |
# --------------------
#
#  [[6066 1025]
#  [ 576 6515]]
# Epoch 11/30
# 6893/6893 [==============================] - 842s 122ms/step - loss: 0.2432 - accuracy: 0.8997 - val_loss: 0.4580 - val_accuracy: 0.8334
#
# Epoch 00011: val_accuracy did not improve from 0.88869
# Predicting test data
# 887/887 [==============================] - 19s 21ms/step
# Done
#
#
# testing time(HH:MM:SS:ms) - 0:00:18.903838
#
#
# ---------------------
# | Balanced Accuracy  |
# ---------------------
#
#     0.8333803412776759
#
#
# ---------------------
# |      Accuracy      |
# ---------------------
#
#     0.8333803412776759
#
#
# -------------------------
# | Classifiction Report |
# -------------------------
#               precision    recall  f1-score   support
#
#            0       0.79      0.90      0.84      7091
#            1       0.89      0.76      0.82      7091
#
#     accuracy                           0.83     14182
#    macro avg       0.84      0.83      0.83     14182
# weighted avg       0.84      0.83      0.83     14182
#
# --------------------
# | Confusion Matrix |
# --------------------
#
#  [[6399  692]
#  [1671 5420]]
# Epoch 12/30
# 6893/6893 [==============================] - 862s 125ms/step - loss: 0.2410 - accuracy: 0.9006 - val_loss: 0.3300 - val_accuracy: 0.8734
#
# Epoch 00012: val_accuracy did not improve from 0.88869
# Predicting test data
# 887/887 [==============================] - 21s 24ms/step
# Done
#
#
# testing time(HH:MM:SS:ms) - 0:00:21.348885
#
#
# ---------------------
# | Balanced Accuracy  |
# ---------------------
#
#     0.873431109857566
#
#
# ---------------------
# |      Accuracy      |
# ---------------------
#
#     0.8734311098575659
#
#
# -------------------------
# | Classifiction Report |
# -------------------------
#               precision    recall  f1-score   support
#
#            0       0.88      0.87      0.87      7091
#            1       0.87      0.88      0.87      7091
#
#     accuracy                           0.87     14182
#    macro avg       0.87      0.87      0.87     14182
# weighted avg       0.87      0.87      0.87     14182
#
# --------------------
# | Confusion Matrix |
# --------------------
#
#  [[6166  925]
#  [ 870 6221]]
# Epoch 13/30
# 6893/6893 [==============================] - 869s 126ms/step - loss: 0.2386 - accuracy: 0.9022 - val_loss: 0.3043 - val_accuracy: 0.8833
#
# Epoch 00013: val_accuracy did not improve from 0.88869
# Predicting test data
# 887/887 [==============================] - 21s 24ms/step
# Done
#
#
# testing time(HH:MM:SS:ms) - 0:00:41.010528
#
#
# ---------------------
# | Balanced Accuracy  |
# ---------------------
#
#     0.8833027781695106
#
#
# ---------------------
# |      Accuracy      |
# ---------------------
#
#     0.8833027781695106
#
#
# -------------------------
# | Classifiction Report |
# -------------------------
#               precision    recall  f1-score   support
#
#            0       0.90      0.86      0.88      7091
#            1       0.87      0.91      0.89      7091
#
#     accuracy                           0.88     14182
#    macro avg       0.88      0.88      0.88     14182
# weighted avg       0.88      0.88      0.88     14182
#
# --------------------
# | Confusion Matrix |
# --------------------
#
#  [[6096  995]
#  [ 660 6431]]
# Epoch 14/30
# 6893/6893 [==============================] - 867s 126ms/step - loss: 0.2370 - accuracy: 0.9030 - val_loss: 0.3386 - val_accuracy: 0.8598
#
# Epoch 00014: val_accuracy did not improve from 0.88869
# Predicting test data
# 887/887 [==============================] - 21s 24ms/step
# Done
#
#
# testing time(HH:MM:SS:ms) - 0:00:21.313517
#
#
# ---------------------
# | Balanced Accuracy  |
# ---------------------
#
#     0.8598928218868989
#
#
# ---------------------
# |      Accuracy      |
# ---------------------
#
#     0.8598928218868989
#
#
# -------------------------
# | Classifiction Report |
# -------------------------
#               precision    recall  f1-score   support
#
#            0       0.92      0.79      0.85      7091
#            1       0.81      0.93      0.87      7091
#
#     accuracy                           0.86     14182
#    macro avg       0.87      0.86      0.86     14182
# weighted avg       0.87      0.86      0.86     14182
#
# --------------------
# | Confusion Matrix |
# --------------------
#
#  [[5571 1520]
#  [ 467 6624]]
# Epoch 15/30
# 6893/6893 [==============================] - 845s 123ms/step - loss: 0.2344 - accuracy: 0.9034 - val_loss: 0.3303 - val_accuracy: 0.8672
#
# Epoch 00015: val_accuracy did not improve from 0.88869
# Predicting test data
# 887/887 [==============================] - 21s 23ms/step
# Done
#
#
# testing time(HH:MM:SS:ms) - 0:00:41.007313
#
#
# ---------------------
# | Balanced Accuracy  |
# ---------------------
#
#     0.8672965731208575
#
#
# ---------------------
# |      Accuracy      |
# ---------------------
#
#     0.8672965731208574
#
#
# -------------------------
# | Classifiction Report |
# -------------------------
#               precision    recall  f1-score   support
#
#            0       0.90      0.83      0.86      7091
#            1       0.84      0.91      0.87      7091
#
#     accuracy                           0.87     14182
#    macro avg       0.87      0.87      0.87     14182
# weighted avg       0.87      0.87      0.87     14182
#
# --------------------
# | Confusion Matrix |
# --------------------
#
#  [[5860 1231]
#  [ 651 6440]]
# Epoch 16/30
# 6893/6893 [==============================] - 853s 124ms/step - loss: 0.2324 - accuracy: 0.9050 - val_loss: 0.3005 - val_accuracy: 0.8791
#
# Epoch 00016: val_accuracy did not improve from 0.88869
# Predicting test data
# 887/887 [==============================] - 21s 24ms/step
# Done
#
#
# testing time(HH:MM:SS:ms) - 0:00:21.529969
#
#
# ---------------------
# | Balanced Accuracy  |
# ---------------------
#
#     0.8791425750951911
#
#
# ---------------------
# |      Accuracy      |
# ---------------------
#
#     0.8791425750951911
#
#
# -------------------------
# | Classifiction Report |
# -------------------------
#               precision    recall  f1-score   support
#
#            0       0.93      0.82      0.87      7091
#            1       0.84      0.93      0.89      7091
#
#     accuracy                           0.88     14182
#    macro avg       0.88      0.88      0.88     14182
# weighted avg       0.88      0.88      0.88     14182
#
# --------------------
# | Confusion Matrix |
# --------------------
#
#  [[5848 1243]
#  [ 471 6620]]
# Epoch 17/30
# 6893/6893 [==============================] - 852s 124ms/step - loss: 0.2302 - accuracy: 0.9063 - val_loss: 0.2691 - val_accuracy: 0.8900
#
# Epoch 00017: val_accuracy improved from 0.88869 to 0.89003, saving model to best_model_multiclass_128.h5
# Predicting test data
# 887/887 [==============================] - 19s 21ms/step
# Done
#
#
# testing time(HH:MM:SS:ms) - 0:00:20.510735
#
#
# ---------------------
# | Balanced Accuracy  |
# ---------------------
#
#     0.8900014102383302
#
#
# ---------------------
# |      Accuracy      |
# ---------------------
#
#     0.8900014102383302
#
#
# -------------------------
# | Classifiction Report |
# -------------------------
#               precision    recall  f1-score   support
#
#            0       0.89      0.89      0.89      7091
#            1       0.89      0.89      0.89      7091
#
#     accuracy                           0.89     14182
#    macro avg       0.89      0.89      0.89     14182
# weighted avg       0.89      0.89      0.89     14182
#
# --------------------
# | Confusion Matrix |
# --------------------
#
#  [[6325  766]
#  [ 794 6297]]
# Epoch 18/30
# 6893/6893 [==============================] - 844s 122ms/step - loss: 0.2284 - accuracy: 0.9069 - val_loss: 0.3232 - val_accuracy: 0.8655
#
# Epoch 00018: val_accuracy did not improve from 0.89003
# Predicting test data
# 887/887 [==============================] - 18s 21ms/step
# Done
#
#
# testing time(HH:MM:SS:ms) - 0:00:18.448481
#
#
# ---------------------
# | Balanced Accuracy  |
# ---------------------
#
#     0.865604287124524
#
#
# ---------------------
# |      Accuracy      |
# ---------------------
#
#     0.8656042871245241
#
#
# -------------------------
# | Classifiction Report |
# -------------------------
#               precision    recall  f1-score   support
#
#            0       0.89      0.84      0.86      7091
#            1       0.85      0.90      0.87      7091
#
#     accuracy                           0.87     14182
#    macro avg       0.87      0.87      0.87     14182
# weighted avg       0.87      0.87      0.87     14182
#
# --------------------
# | Confusion Matrix |
# --------------------
#
#  [[5929 1162]
#  [ 744 6347]]
# Epoch 19/30
# 6893/6893 [==============================] - 859s 125ms/step - loss: 0.2267 - accuracy: 0.9068 - val_loss: 0.3794 - val_accuracy: 0.8701
#
# Epoch 00019: val_accuracy did not improve from 0.89003
# Predicting test data
# 887/887 [==============================] - 22s 25ms/step
# Done
#
#
# testing time(HH:MM:SS:ms) - 0:00:41.008014
#
#
# ---------------------
# | Balanced Accuracy  |
# ---------------------
#
#     0.8701875616979269
#
#
# ---------------------
# |      Accuracy      |
# ---------------------
#
#     0.870187561697927
#
#
# -------------------------
# | Classifiction Report |
# -------------------------
#               precision    recall  f1-score   support
#
#            0       0.93      0.80      0.86      7091
#            1       0.83      0.94      0.88      7091
#
#     accuracy                           0.87     14182
#    macro avg       0.88      0.87      0.87     14182
# weighted avg       0.88      0.87      0.87     14182
#
# --------------------
# | Confusion Matrix |
# --------------------
#
#  [[5691 1400]
#  [ 441 6650]]
# Epoch 20/30
# 6893/6893 [==============================] - 839s 122ms/step - loss: 0.2246 - accuracy: 0.9077 - val_loss: 0.3283 - val_accuracy: 0.8725
#
# Epoch 00020: val_accuracy did not improve from 0.89003
# Predicting test data
# 887/887 [==============================] - 19s 21ms/step
# Done
#
#
# testing time(HH:MM:SS:ms) - 0:00:18.631767
#
#
# ---------------------
# | Balanced Accuracy  |
# ---------------------
#
#     0.8724439430263714
#
#
# ---------------------
# |      Accuracy      |
# ---------------------
#
#     0.8724439430263714
#
#
# -------------------------
# | Classifiction Report |
# -------------------------
#               precision    recall  f1-score   support
#
#            0       0.94      0.80      0.86      7091
#            1       0.82      0.95      0.88      7091
#
#     accuracy                           0.87     14182
#    macro avg       0.88      0.87      0.87     14182
# weighted avg       0.88      0.87      0.87     14182
#
# --------------------
# | Confusion Matrix |
# --------------------
#
#  [[5657 1434]
#  [ 375 6716]]
# Epoch 21/30
# 6893/6893 [==============================] - 844s 122ms/step - loss: 0.2229 - accuracy: 0.9087 - val_loss: 0.3294 - val_accuracy: 0.8701
#
# Epoch 00021: val_accuracy did not improve from 0.89003
# Predicting test data
# 887/887 [==============================] - 18s 20ms/step
# Done
#
#
# testing time(HH:MM:SS:ms) - 0:00:18.225662
#
#
# ---------------------
# | Balanced Accuracy  |
# ---------------------
#
#     0.8700465378648992
#
#
# ---------------------
# |      Accuracy      |
# ---------------------
#
#     0.8700465378648992
#
#
# -------------------------
# | Classifiction Report |
# -------------------------
#               precision    recall  f1-score   support
#
#            0       0.94      0.79      0.86      7091
#            1       0.82      0.95      0.88      7091
#
#     accuracy                           0.87     14182
#    macro avg       0.88      0.87      0.87     14182
# weighted avg       0.88      0.87      0.87     14182
#
# --------------------
# | Confusion Matrix |
# --------------------
#
#  [[5634 1457]
#  [ 386 6705]]
# Epoch 22/30
# 6893/6893 [==============================] - 856s 124ms/step - loss: 0.2198 - accuracy: 0.9096 - val_loss: 0.2894 - val_accuracy: 0.8847
#
# Epoch 00022: val_accuracy did not improve from 0.89003
# Predicting test data
# 887/887 [==============================] - 22s 25ms/step
# Done
#
#
# testing time(HH:MM:SS:ms) - 0:00:41.008836
#
#
# ---------------------
# | Balanced Accuracy  |
# ---------------------
#
#     0.8847835284163024
#
#
# ---------------------
# |      Accuracy      |
# ---------------------
#
#     0.8847835284163024
#
#
# -------------------------
# | Classifiction Report |
# -------------------------
#               precision    recall  f1-score   support
#
#            0       0.91      0.85      0.88      7091
#            1       0.86      0.92      0.89      7091
#
#     accuracy                           0.88     14182
#    macro avg       0.89      0.88      0.88     14182
# weighted avg       0.89      0.88      0.88     14182
#
# --------------------
# | Confusion Matrix |
# --------------------
#
#  [[6040 1051]
#  [ 583 6508]]
# Epoch 23/30
# 6893/6893 [==============================] - 845s 123ms/step - loss: 0.2200 - accuracy: 0.9096 - val_loss: 1.0103 - val_accuracy: 0.8619
#
# Epoch 00023: val_accuracy did not improve from 0.89003
# Predicting test data
# 887/887 [==============================] - 19s 21ms/step
# Done
#
#
# testing time(HH:MM:SS:ms) - 0:00:18.632562
#
#
# ---------------------
# | Balanced Accuracy  |
# ---------------------
#
#     0.8619376674658017
#
#
# ---------------------
# |      Accuracy      |
# ---------------------
#
#     0.8619376674658017
#
#
# -------------------------
# | Classifiction Report |
# -------------------------
#               precision    recall  f1-score   support
#
#            0       0.90      0.82      0.86      7091
#            1       0.83      0.90      0.87      7091
#
#     accuracy                           0.86     14182
#    macro avg       0.86      0.86      0.86     14182
# weighted avg       0.86      0.86      0.86     14182
#
# --------------------
# | Confusion Matrix |
# --------------------
#
#  [[5814 1277]
#  [ 681 6410]]
# Epoch 24/30
# 6893/6893 [==============================] - 841s 122ms/step - loss: 0.2168 - accuracy: 0.9105 - val_loss: 1.1202 - val_accuracy: 0.8541
#
# Epoch 00024: val_accuracy did not improve from 0.89003
# Predicting test data
# 887/887 [==============================] - 23s 26ms/step
# Done
#
#
# testing time(HH:MM:SS:ms) - 0:00:41.009030
#
#
# ---------------------
# | Balanced Accuracy  |
# ---------------------
#
#     0.8541108447327599
#
#
# ---------------------
# |      Accuracy      |
# ---------------------
#
#     0.8541108447327599
#
#
# -------------------------
# | Classifiction Report |
# -------------------------
#               precision    recall  f1-score   support
#
#            0       0.87      0.84      0.85      7091
#            1       0.84      0.87      0.86      7091
#
#     accuracy                           0.85     14182
#    macro avg       0.85      0.85      0.85     14182
# weighted avg       0.85      0.85      0.85     14182
#
# --------------------
# | Confusion Matrix |
# --------------------
#
#  [[5926 1165]
#  [ 904 6187]]
# Epoch 25/30
# 6893/6893 [==============================] - 841s 122ms/step - loss: 0.2145 - accuracy: 0.9117 - val_loss: 0.5475 - val_accuracy: 0.8624
#
# Epoch 00025: val_accuracy did not improve from 0.89003
# Predicting test data
# 887/887 [==============================] - 19s 21ms/step
# Done
#
#
# testing time(HH:MM:SS:ms) - 0:00:20.509999
#
#
# ---------------------
# | Balanced Accuracy  |
# ---------------------
#
#     0.8625017627979128
#
#
# ---------------------
# |      Accuracy      |
# ---------------------
#
#     0.8625017627979128
#
#
# -------------------------
# | Classifiction Report |
# -------------------------
#               precision    recall  f1-score   support
#
#            0       0.88      0.84      0.86      7091
#            1       0.84      0.89      0.87      7091
#
#     accuracy                           0.86     14182
#    macro avg       0.86      0.86      0.86     14182
# weighted avg       0.86      0.86      0.86     14182
#
# --------------------
# | Confusion Matrix |
# --------------------
#
#  [[5934 1157]
#  [ 793 6298]]
# Epoch 26/30
# 6893/6893 [==============================] - 843s 122ms/step - loss: 0.2138 - accuracy: 0.9120 - val_loss: 1.2162 - val_accuracy: 0.8579
#
# Epoch 00026: val_accuracy did not improve from 0.89003
# Predicting test data
# 887/887 [==============================] - 19s 21ms/step
# Done
#
#
# testing time(HH:MM:SS:ms) - 0:00:18.819750
#
#
# ---------------------
# | Balanced Accuracy  |
# ---------------------
#
#     0.8579890001410237
#
#
# ---------------------
# |      Accuracy      |
# ---------------------
#
#     0.8579890001410239
#
#
# -------------------------
# | Classifiction Report |
# -------------------------
#               precision    recall  f1-score   support
#
#            0       0.90      0.80      0.85      7091
#            1       0.82      0.91      0.87      7091
#
#     accuracy                           0.86     14182
#    macro avg       0.86      0.86      0.86     14182
# weighted avg       0.86      0.86      0.86     14182
#
# --------------------
# | Confusion Matrix |
# --------------------
#
#  [[5684 1407]
#  [ 607 6484]]
# Epoch 27/30
# 6893/6893 [==============================] - 842s 122ms/step - loss: 0.2100 - accuracy: 0.9143 - val_loss: 0.3504 - val_accuracy: 0.8669
#
# Epoch 00027: val_accuracy did not improve from 0.89003
# Predicting test data
# 887/887 [==============================] - 19s 21ms/step
# Done
#
#
# testing time(HH:MM:SS:ms) - 0:00:20.513654
#
#
# ---------------------
# | Balanced Accuracy  |
# ---------------------
#
#     0.8668735016217741
#
#
# ---------------------
# |      Accuracy      |
# ---------------------
#
#     0.8668735016217741
#
#
# -------------------------
# | Classifiction Report |
# -------------------------
#               precision    recall  f1-score   support
#
#            0       0.92      0.80      0.86      7091
#            1       0.83      0.93      0.87      7091
#
#     accuracy                           0.87     14182
#    macro avg       0.87      0.87      0.87     14182
# weighted avg       0.87      0.87      0.87     14182
#
# --------------------
# | Confusion Matrix |
# --------------------
#
#  [[5700 1391]
#  [ 497 6594]]
# Epoch 28/30
# 6893/6893 [==============================] - 843s 122ms/step - loss: 0.2093 - accuracy: 0.9144 - val_loss: 0.4929 - val_accuracy: 0.8608
#
# Epoch 00028: val_accuracy did not improve from 0.89003
# Predicting test data
# 887/887 [==============================] - 19s 21ms/step
# Done
#
#
# testing time(HH:MM:SS:ms) - 0:00:18.589688
#
#
# ---------------------
# | Balanced Accuracy  |
# ---------------------
#
#     0.8608094768015795
#
#
# ---------------------
# |      Accuracy      |
# ---------------------
#
#     0.8608094768015795
#
#
# -------------------------
# | Classifiction Report |
# -------------------------
#               precision    recall  f1-score   support
#
#            0       0.84      0.89      0.86      7091
#            1       0.88      0.83      0.86      7091
#
#     accuracy                           0.86     14182
#    macro avg       0.86      0.86      0.86     14182
# weighted avg       0.86      0.86      0.86     14182
#
# --------------------
# | Confusion Matrix |
# --------------------
#
#  [[6299  792]
#  [1182 5909]]
# Epoch 29/30
# 6893/6893 [==============================] - 842s 122ms/step - loss: 0.2084 - accuracy: 0.9155 - val_loss: 0.3341 - val_accuracy: 0.8747
#
# Epoch 00029: val_accuracy did not improve from 0.89003
# Predicting test data
# 887/887 [==============================] - 18s 21ms/step
# Done
#
#
# testing time(HH:MM:SS:ms) - 0:00:20.512926
#
#
# ---------------------
# | Balanced Accuracy  |
# ---------------------
#
#     0.8747708362713298
#
#
# ---------------------
# |      Accuracy      |
# ---------------------
#
#     0.8747708362713299
#
#
# -------------------------
# | Classifiction Report |
# -------------------------
#               precision    recall  f1-score   support
#
#            0       0.88      0.87      0.87      7091
#            1       0.87      0.88      0.87      7091
#
#     accuracy                           0.87     14182
#    macro avg       0.87      0.87      0.87     14182
# weighted avg       0.87      0.87      0.87     14182
#
# --------------------
# | Confusion Matrix |
# --------------------
#
#  [[6199  892]
#  [ 884 6207]]
# Epoch 30/30
# 6893/6893 [==============================] - 844s 122ms/step - loss: 0.2053 - accuracy: 0.9165 - val_loss: 0.3108 - val_accuracy: 0.8768
#
# Epoch 00030: val_accuracy did not improve from 0.89003
# Predicting test data
# 887/887 [==============================] - 19s 21ms/step
# Done
#
#
# testing time(HH:MM:SS:ms) - 0:00:18.988755
#
#
# ---------------------
# | Balanced Accuracy  |
# ---------------------
#
#     0.8768861937667466
#
#
# ---------------------
# |      Accuracy      |
# ---------------------
#
#     0.8768861937667466
#
#
# -------------------------
# | Classifiction Report |
# -------------------------
#               precision    recall  f1-score   support
#
#            0       0.92      0.82      0.87      7091
#            1       0.84      0.93      0.88      7091
#
#     accuracy                           0.88     14182
#    macro avg       0.88      0.88      0.88     14182
# weighted avg       0.88      0.88      0.88     14182
#
# --------------------
# | Confusion Matrix |
# --------------------
#
#  [[5837 1254]
#  [ 492 6599]]

# %% [markdown]
# # Loading Best Model

# %%
from keras.models import load_model
best_model = load_model('./best_model_multiclass_128.h5')

# %% [markdown]
# # Best Model Performance
# def test_final_model(model, train_generator, test_generator, val_generator, y_train, y_test, y_val, class_labels, cm_normalize=True, \
#                  print_cm=True):

# %%
'''
test_model(best_model, 
           val_generator,
           y_test = np.argmax(test_label, axis = 1),
           class_labels = ['Normal', 'Viral', 'Bacterial'])
           '''
#must use train_label1 as train_label went through a shuffle in image-data-generator
test_final_model(best_model, train_generator, 
               val_generator, val2_generator, 
               np.argmax(train_label1, axis=1),
               np.argmax(test_label, axis=1),
               np.argmax(val_label, axis=1), 
               class_labels = ['idc-', 'idc+'])
# Out:
# Predicting test data
# 887/887 [==============================] - 21s 21ms/step
# Done
#
#
# testing time(HH:MM:SS:ms) - 0:00:22.858160
#
#
# ---------------------
# | Balanced Accuracy  |
# ---------------------
#
#     0.8900014102383302
#
#
# ---------------------
# |      Accuracy      |
# ---------------------
#
#     0.8900014102383302
#
#
# -------------------------
# | Classifiction Report |
# -------------------------
#               precision    recall  f1-score   support
#
#            0       0.89      0.89      0.89      7091
#            1       0.89      0.89      0.89      7091
#
#     accuracy                           0.89     14182
#    macro avg       0.89      0.89      0.89     14182
# weighted avg       0.89      0.89      0.89     14182
#
# --------------------
# | Confusion Matrix |
# --------------------
#
#  [[6325  766]
#  [ 794 6297]]
# calculate other score
# predicting validation data
# 2069/2069 [==============================] - 43s 21ms/step
# predicting test data
# 6894/6894 [==============================] - 186s 27ms/step
# Train accuracy Score------------>
# 49.965 %
# Val accuracy Score--------->
# 88.616 %
# Test accuracy Score--------->
# 89.000 %
# F1 Score--------------->
# 89.000 %
# Cohen Kappa Score------------->
# 78.000 %
# Recall-------------->
# 89.000 %
# Precision-------------->
# 89.001 %

# %% [markdown]
# # Plotting EpochPlot

# %%
import matplotlib.pyplot as plt
import seaborn as sns
sns.set()
acc = model.history.history['accuracy']
val_acc = model.history.history['val_accuracy']
loss = model.history.history['loss']
val_loss = model.history.history['val_loss']

epochs = range(0,len(acc))
fig = plt.gcf()
fig.set_size_inches(16, 8)

plt.plot(epochs, acc, 'r', label='Training accuracy',marker = "o")
plt.plot(epochs, val_acc, 'b', label='Validation accuracy',marker = "o")
plt.title('Training and validation accuracy')
plt.xticks(np.arange(0, len(acc), 10))
plt.legend(loc=0)
plt.figure()

fig = plt.gcf()
fig.set_size_inches(16, 8)
plt.plot(epochs, loss, 'r', label='Training Loss',marker = "o")
plt.plot(epochs, val_loss, 'b', label='Validation Loss',marker = "o")
plt.title('Training and validation Loss')
plt.xticks(np.arange(0, len(acc), 10))
plt.legend(loc=0)
#plt.savefig('Multiclass Model .png')
plt.figure()
plt.show()

# %%
#print(y_test)

# %% [markdown]
# from sklearn.cross_validation import train_test_split# Grad-CAM and Saliency Map
# coming soon....
